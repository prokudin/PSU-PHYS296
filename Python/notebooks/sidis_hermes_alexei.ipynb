# %% [markdown]
# # JAM FITTER

# %%
import sys,os
from fitlab.resman import RESMAN
from fitlab.mcsamp import MCSAMP
from tools.config import load_config,conf
from tools.tools import load, save,checkdir
import pylab as py
import numpy as np
import pandas as pd
import copy
def lprint(msg):
    sys.stdout.write('\r')
    sys.stdout.write('%s' %msg)
    sys.stdout.flush()
# %matplotlib inline

# %% [markdown]
# ## setup path to store the results

# %%
path2results='sidis_hermes_alexei'
checkdir(path2results)

# %% [markdown]
# ## data sets

# %%
conf['datasets']={}

# %% [markdown]
# ## SIDIS FUU

# %%
conf['datasets']['sidis']={}
conf['datasets']['sidis']['filters']={}
conf['datasets']['sidis']['filters'][0]={}
conf['datasets']['sidis']['filters'][0]['idx']=[1000,1001,1004,1005,1002,1003,1006,1007]
conf['datasets']['sidis']['filters'][0]['filter']="z>0.2 and z<0.6 and Q2>1.69 and (pT/z)**2<0.25*Q2 and dy>2.5"
#conf['datasets']['sidis']['filters'][0]['filter']="z>0.2 and z<0.6 and Q2>1."



conf['datasets']['sidis']['xlsx']={}
conf['datasets']['sidis']['xlsx'][1000]='../database/sidis/expdata/1000.xlsx'  # |  proton   | pi+    | M_Hermes | hermes 
conf['datasets']['sidis']['xlsx'][1001]='../database/sidis/expdata/1001.xlsx'  # |  proton   | pi-    | M_Hermes | hermes 
conf['datasets']['sidis']['xlsx'][1004]='../database/sidis/expdata/1004.xlsx'  # |  deuteron | pi+    | M_Hermes | hermes 
conf['datasets']['sidis']['xlsx'][1005]='../database/sidis/expdata/1005.xlsx'  # |  deuteron | pi-    | M_Hermes | hermes 

conf['datasets']['sidis']['xlsx'][1002]='../database/sidis/expdata/1002.xlsx'  # |  proton   | k+    | M_Hermes | hermes 
conf['datasets']['sidis']['xlsx'][1003]='../database/sidis/expdata/1003.xlsx'  # |  proton   | k-    | M_Hermes | hermes 
conf['datasets']['sidis']['xlsx'][1006]='../database/sidis/expdata/1006.xlsx'  # |  deuteron | k+    | M_Hermes | hermes 
conf['datasets']['sidis']['xlsx'][1007]='../database/sidis/expdata/1007.xlsx'  # |  deuteron | k-    | M_Hermes | hermes 

conf['datasets']['sidis']['norm']={}
for k in conf['datasets']['sidis']['xlsx']: conf['datasets']['sidis']['norm'][k]={'value':1,'fixed':True,'min':0,'max':1}

# %% [markdown]
# ## parameters

# %%
conf['params']={}

# %% [markdown]
# ### pion PDF parameters

# %%
conf['params']['pdf']={}
conf['params']['pdf']['widths0 valence']  = {'value':0.32268,'fixed':False,'min':0.2,'max':0.5}
conf['params']['pdf']['widths0 sea']      = {'value':0.46650,'fixed':False,'min':0.3,'max':0.8}

# %%
conf['params']['ff']={}
conf['params']['ff']['widths0 pi+ fav']   = {'value':0.20764,'fixed':False,'min':0.1,'max':0.3}
conf['params']['ff']['widths0 pi+ unfav'] = {'value':0.18564,'fixed':False,'min':0.1,'max':0.3}
conf['params']['ff']['widths0 k+ fav']    = {'value':0.23880,'fixed':False,'min':0.1,'max':0.4}
conf['params']['ff']['widths0 k+ unfav']  = {'value':0.11432,'fixed':False,'min':0.05,'max':0.4}

# %% [markdown]
# ## Nested Sampling

# %% [markdown]
# ### initialize fitpack libraries

# %%
conf['resman'] = RESMAN()
mcsamp=MCSAMP()
# Out:
# loading sidis data sets 1007

# %%
conf['params']
# Out:
# {'ff': {'widths0 k+ fav': {'fixed': False,
#    'max': 1,
#    'min': 0,
#    'value': 0.29503341072807754},
#   'widths0 k+ unfav': {'fixed': False,
#    'max': 1,
#    'min': 0,
#    'value': 0.16063983977068658},
#   'widths0 pi+ fav': {'fixed': False, 'max': 1, 'min': 0, 'value': 0.5},
#   'widths0 pi+ unfav': {'fixed': False, 'max': 1, 'min': 0, 'value': 0.5}},
#  'pdf': {'widths0 sea': {'fixed': False, 'max': 1, 'min': 0, 'value': 0.5},
#   'widths0 valence': {'fixed': False, 'max': 1, 'min': 0, 'value': 0.5}}}

# %%
from fitlab.maxlike import ML
from qcdlib.aux import AUX
from fitlab.parman import PARMAN
conf['parman'] = PARMAN()
conf['aux']=AUX()
ML().run_minimize()
# Out:
# JAM FITTER
# count = 1
# elapsed time(mins)=0.006908
# shifts  = 0
# npts    = 417
# chi2    = 664.789934
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789934
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 2
# elapsed time(mins)=0.013218
# shifts  = 0
# npts    = 417
# chi2    = 664.789934
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789934
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 3
# elapsed time(mins)=0.019734
# shifts  = 1
# npts    = 417
# chi2    = 664.789944
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789944
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 4
# elapsed time(mins)=0.026504
# shifts  = 2
# npts    = 417
# chi2    = 664.789935
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789935
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 5
# elapsed time(mins)=0.033893
# shifts  = 2
# npts    = 417
# chi2    = 664.789936
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789936
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 6
# elapsed time(mins)=0.041444
# shifts  = 2
# npts    = 417
# chi2    = 664.789958
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789958
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 7
# elapsed time(mins)=0.049020
# shifts  = 2
# npts    = 417
# chi2    = 664.789991
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789991
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 8
# elapsed time(mins)=0.056244
# shifts  = 2
# npts    = 417
# chi2    = 664.789937
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789937
# dchi2(iter)  = 0.000000
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 9
# elapsed time(mins)=0.063139
# shifts  = 6
# npts    = 417
# chi2    = 664.789907
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789907
# dchi2(iter)  = inf
# dchi2(local) = -inf
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 10
# elapsed time(mins)=0.070245
# shifts  = 0
# npts    = 417
# chi2    = 664.789907
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789907
# dchi2(iter)  = inf
# dchi2(local) = 0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 11
# elapsed time(mins)=0.076723
# shifts  = 1
# npts    = 417
# chi2    = 664.789918
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789918
# dchi2(iter)  = inf
# dchi2(local) = 0.000011
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 12
# elapsed time(mins)=0.083832
# shifts  = 2
# npts    = 417
# chi2    = 664.789909
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789909
# dchi2(iter)  = inf
# dchi2(local) = 0.000001
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 13
# elapsed time(mins)=0.090287
# shifts  = 2
# npts    = 417
# chi2    = 664.789909
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789909
# dchi2(iter)  = inf
# dchi2(local) = 0.000002
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 14
# elapsed time(mins)=0.096849
# shifts  = 2
# npts    = 417
# chi2    = 664.789931
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789931
# dchi2(iter)  = inf
# dchi2(local) = 0.000024
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 15
# elapsed time(mins)=0.103428
# shifts  = 2
# npts    = 417
# chi2    = 664.789965
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789965
# dchi2(iter)  = inf
# dchi2(local) = 0.000057
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 16
# elapsed time(mins)=0.110171
# shifts  = 2
# npts    = 417
# chi2    = 664.789910
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789910
# dchi2(iter)  = inf
# dchi2(local) = 0.000003
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 17
# elapsed time(mins)=0.117342
# shifts  = 6
# npts    = 417
# chi2    = 664.789934
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789934
# dchi2(iter)  = inf
# dchi2(local) = 0.000026
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 18
# elapsed time(mins)=0.124496
# shifts  = 0
# npts    = 417
# chi2    = 664.789934
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789934
# dchi2(iter)  = inf
# dchi2(local) = 0.000026
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 19
# elapsed time(mins)=0.131525
# shifts  = 1
# npts    = 417
# chi2    = 664.789944
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789944
# dchi2(iter)  = inf
# dchi2(local) = 0.000037
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 20
# elapsed time(mins)=0.138782
# shifts  = 2
# npts    = 417
# chi2    = 664.789935
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789935
# dchi2(iter)  = inf
# dchi2(local) = 0.000027
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 21
# elapsed time(mins)=0.145974
# shifts  = 2
# npts    = 417
# chi2    = 664.789935
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789935
# dchi2(iter)  = inf
# dchi2(local) = 0.000028
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 22
# elapsed time(mins)=0.153365
# shifts  = 2
# npts    = 417
# chi2    = 664.789957
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789957
# dchi2(iter)  = inf
# dchi2(local) = 0.000050
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 23
# elapsed time(mins)=0.161038
# shifts  = 2
# npts    = 417
# chi2    = 664.789991
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789991
# dchi2(iter)  = inf
# dchi2(local) = 0.000084
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 24
# elapsed time(mins)=0.168235
# shifts  = 2
# npts    = 417
# chi2    = 664.789936
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 664.789936
# dchi2(iter)  = inf
# dchi2(local) = 0.000029
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     163.39       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     129.93       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.79       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.99       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      95.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.90       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      21.44       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      77.62       0.00       0.00
# pdf         widths0 sea            4.66500e-01
# pdf         widths0 valence        3.22680e-01
# ff          widths0 k+ fav         2.38800e-01
# ff          widths0 k+ unfav       1.14320e-01
# ff          widths0 pi+ fav        2.07640e-01
# ff          widths0 pi+ unfav      1.85640e-01
# JAM FITTER
# count = 25
# elapsed time(mins)=0.175387
# shifts  = 6
# npts    = 417
# chi2    = 643.659549
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659549
# dchi2(iter)  = 21.130358
# dchi2(local) = -21.130358
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 26
# elapsed time(mins)=0.182467
# shifts  = 0
# npts    = 417
# chi2    = 643.659549
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659549
# dchi2(iter)  = 21.130358
# dchi2(local) = 0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 27
# elapsed time(mins)=0.189767
# shifts  = 1
# npts    = 417
# chi2    = 643.659545
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659545
# dchi2(iter)  = 21.130358
# dchi2(local) = -0.000005
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 28
# elapsed time(mins)=0.197073
# shifts  = 2
# npts    = 417
# chi2    = 643.659549
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659549
# dchi2(iter)  = 21.130358
# dchi2(local) = -0.000001
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 29
# elapsed time(mins)=0.204336
# shifts  = 2
# npts    = 417
# chi2    = 643.659545
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659545
# dchi2(iter)  = 21.130358
# dchi2(local) = -0.000005
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 30
# elapsed time(mins)=0.211485
# shifts  = 2
# npts    = 417
# chi2    = 643.659558
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659558
# dchi2(iter)  = 21.130358
# dchi2(local) = 0.000009
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 31
# elapsed time(mins)=0.218702
# shifts  = 2
# npts    = 417
# chi2    = 643.659527
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659527
# dchi2(iter)  = 21.130358
# dchi2(local) = -0.000022
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 32
# elapsed time(mins)=0.225730
# shifts  = 2
# npts    = 417
# chi2    = 643.659542
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 643.659542
# dchi2(iter)  = 21.130358
# dchi2(local) = -0.000007
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.64       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     122.11       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      57.57       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      22.07       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      96.49       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     104.34       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      17.64       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      81.79       0.00       0.00
# pdf         widths0 sea            4.65460e-01
# pdf         widths0 valence        3.24139e-01
# ff          widths0 k+ fav         2.26884e-01
# ff          widths0 k+ unfav       7.18628e-02
# ff          widths0 pi+ fav        1.87554e-01
# ff          widths0 pi+ unfav      1.93900e-01
# JAM FITTER
# count = 33
# elapsed time(mins)=0.232825
# shifts  = 6
# npts    = 417
# chi2    = 630.245755
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245755
# dchi2(iter)  = 13.413794
# dchi2(local) = -13.413794
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 34
# elapsed time(mins)=0.239618
# shifts  = 0
# npts    = 417
# chi2    = 630.245755
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245755
# dchi2(iter)  = 13.413794
# dchi2(local) = 0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 35
# elapsed time(mins)=0.246103
# shifts  = 1
# npts    = 417
# chi2    = 630.245759
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245759
# dchi2(iter)  = 13.413794
# dchi2(local) = 0.000004
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 36
# elapsed time(mins)=0.253036
# shifts  = 2
# npts    = 417
# chi2    = 630.245755
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245755
# dchi2(iter)  = 13.413794
# dchi2(local) = 0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 37
# elapsed time(mins)=0.260385
# shifts  = 2
# npts    = 417
# chi2    = 630.245754
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245754
# dchi2(iter)  = 13.413794
# dchi2(local) = -0.000001
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 38
# elapsed time(mins)=0.267547
# shifts  = 2
# npts    = 417
# chi2    = 630.245772
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245772
# dchi2(iter)  = 13.413794
# dchi2(local) = 0.000017
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 39
# elapsed time(mins)=0.273937
# shifts  = 2
# npts    = 417
# chi2    = 630.245777
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245777
# dchi2(iter)  = 13.413794
# dchi2(local) = 0.000022
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      55.26       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.84       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      89.87       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.96       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      19.41       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      75.51       0.00       0.00
# pdf         widths0 sea            4.65980e-01
# pdf         widths0 valence        3.23409e-01
# ff          widths0 k+ fav         2.32842e-01
# ff          widths0 k+ unfav       9.30914e-02
# ff          widths0 pi+ fav        1.97597e-01
# ff          widths0 pi+ unfav      1.89770e-01
# JAM FITTER
# count = 40
# elapsed time(mins)=0.281164
# shifts  = 2
# npts    = 417
# chi2    = 630.245754
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 630.245754
# dchi2(iter)  = 13.413794
# dchi2(local) = -0.000001
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     141.22       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     126.17       0.00       0.00
# ...
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.399433
# dchi2(iter)  = 0.000759
# dchi2(local) = -0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.57       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.71       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.72       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.48       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.19       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84228e-01
# pdf         widths0 valence        3.34008e-01
# ff          widths0 k+ fav         2.33473e-01
# ff          widths0 k+ unfav       9.29507e-02
# ff          widths0 pi+ fav        1.93773e-01
# ff          widths0 pi+ unfav      1.79549e-01
# JAM FITTER
# count = 799
# elapsed time(mins)=5.710747
# shifts  = 2
# npts    = 417
# chi2    = 619.399434
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.399434
# dchi2(iter)  = 0.000759
# dchi2(local) = -0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.57       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.71       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.72       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.48       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.19       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84228e-01
# pdf         widths0 valence        3.34008e-01
# ff          widths0 k+ fav         2.33473e-01
# ff          widths0 k+ unfav       9.29507e-02
# ff          widths0 pi+ fav        1.93773e-01
# ff          widths0 pi+ unfav      1.79549e-01
# JAM FITTER
# count = 800
# elapsed time(mins)=5.718263
# shifts  = 2
# npts    = 417
# chi2    = 619.399434
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.399434
# dchi2(iter)  = 0.000759
# dchi2(local) = -0.000000
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.57       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.71       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.72       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.48       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.19       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84228e-01
# pdf         widths0 valence        3.34008e-01
# ff          widths0 k+ fav         2.33473e-01
# ff          widths0 k+ unfav       9.29507e-02
# ff          widths0 pi+ fav        1.93773e-01
# ff          widths0 pi+ unfav      1.79549e-01
# JAM FITTER
# count = 801
# elapsed time(mins)=5.725562
# shifts  = 6
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 802
# elapsed time(mins)=5.735808
# shifts  = 0
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 803
# elapsed time(mins)=5.742911
# shifts  = 1
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 804
# elapsed time(mins)=5.749511
# shifts  = 2
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 805
# elapsed time(mins)=5.759492
# shifts  = 2
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 806
# elapsed time(mins)=5.767298
# shifts  = 2
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 807
# elapsed time(mins)=5.774438
# shifts  = 2
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 808
# elapsed time(mins)=5.782191
# shifts  = 2
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# JAM FITTER
# count = 809
# elapsed time(mins)=5.789974
# shifts  = 1
# npts    = 417
# chi2    = 619.400241
# rchi2   = 0.000000
# nchi2   = 0.000000
# chi2tot = 619.400241
# dchi2(iter)  = 0.000759
# dchi2(local) = 0.000807
#
# sidis
#    1000     proton        pi+     hermes   M_Hermes    60     138.18       0.00       0.00
#    1001     proton        pi-     hermes   M_Hermes    60     119.58       0.00       0.00
#    1002     proton         k+     hermes   M_Hermes    44      53.70       0.00       0.00
#    1003     proton         k-     hermes   M_Hermes    44      19.81       0.00       0.00
#    1004   deuteron        pi+     hermes   M_Hermes    60      90.73       0.00       0.00
#    1005   deuteron        pi-     hermes   M_Hermes    60     102.47       0.00       0.00
#    1006   deuteron         k+     hermes   M_Hermes    45      20.21       0.00       0.00
#    1007   deuteron         k-     hermes   M_Hermes    44      74.72       0.00       0.00
# pdf         widths0 sea            4.84133e-01
# pdf         widths0 valence        3.34015e-01
# ff          widths0 k+ fav         2.33513e-01
# ff          widths0 k+ unfav       9.29300e-02
# ff          widths0 pi+ fav        1.93752e-01
# ff          widths0 pi+ unfav      1.79612e-01
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-199c84d77a57> in <module>()
#       4 conf['parman'] = PARMAN()
#       5 conf['aux']=AUX()
# ----> 6 ML().run_minimize()
#
# /Users/avp5627/GIT/PSU-PHYS296/Python/fitlab/maxlike.pyc in run_minimize(self)
#     159
#     160     res = minimize(self.get_chi2,guess, bounds=bounds,method='TNC')
# --> 161     res=self.get_residuals(res.x,delay=True)
#     162
#     163   def run_leastsq(self,gen_output=True):
#
# /Users/avp5627/GIT/PSU-PHYS296/Python/fitlab/maxlike.pyc in get_residuals(self, par, delay)
#      92     self.cnt+=1
#      93     res,rres,nres=conf['resman'].get_residuals(par)
# ---> 94     self.get_stats(res,rres,nres,delay)
#      95     if len(rres)!=0: res=np.append(res,rres)
#      96     if len(nres)!=0: res=np.append(res,nres)
#
# /Users/avp5627/GIT/PSU-PHYS296/Python/fitlab/maxlike.pyc in get_stats(self, res, rres, nres, delay)
#      86       for i in range(len(parstatus)): print parstatus[i]
#      87       if delay==True:
# ---> 88         self.gen_output()
#      89         sys.exit()
#      90
#
# /Users/avp5627/GIT/PSU-PHYS296/Python/fitlab/maxlike.pyc in gen_output(self)
#      99   def gen_output(self):
#     100
# --> 101     inputfile=conf['args'].config
#     102     L=open(inputfile).readlines()
#     103     for i in range(len(L)):
#
# KeyError: 'args'

# %% [markdown]
# ### start multiple NS runs
# - the code will start n independent runs specified by size

# %%
conf['size']=10
conf['factor']=4 # play with the factor (3,4) and the tolerance (1.e-5,1.e-10)
conf['tol']=1e-10
mcsamp.run(path2results)
# Out:
# iter=1303  logz=-117.099 rel-err=9.936e-11  t-elapsed=2.170e+03  dchi2min=1.957e+02 dchi2max=1.957e+02

# %% [markdown]
# ### combine multiple runs into one big run

# %%
MC=mcsamp.get_MC_samples(path2results+'/mcdata')
# Out:
# runs max likelihoods
# 96.9702780169
# 97.0086933626
# 96.9702782655
# 96.9702781337
# 97.1595766174
# 96.9702781864
# 96.970278072
# 96.9702782134
# 96.9702780528
# 97.8276265614
# sample  size= 10863
# sample2 size= 1549

# %% [markdown]
# ### distribution of parameters

# %%
samples=MC['samples']
samples2=MC['samples2']
weights=MC['weights']
weights2=MC['weights2']
order=MC['order']
runs=MC['runs']

nrows,ncols=3,2
fig = py.figure(figsize=(ncols*3,nrows*2))

def get_idx(key,tag):
    for i in range(len(order)):
        if order[i][1]==key and order[i][2]==tag:
            return i

def title(tags,i):
    if tags[i] == 'widths0 valence':
        return r"$\langle k_\perp^2 \rangle_{valence}$ (GeV$^2$)"
    if tags[i] == 'widths0 sea':
        return r"$\langle k_\perp^2 \rangle_{sea}$ (GeV$^2$)"
    if tags[i] == 'widths0 pi+ fav':
        return r"$\langle p_\perp^2 \rangle_{\pi^+ fav}$ (GeV$^2$)"
    if tags[i] == 'widths0 pi+ unfav':
        return r"$\langle p_\perp^2 \rangle_{\pi^+ unfav}$ (GeV$^2$)"
    if tags[i] == 'widths0 k+ fav':
        return r"$\langle p_\perp^2 \rangle_{K^+ fav}$ (GeV$^2$)"
    if tags[i] == 'widths0 k+ unfav':
        return r"$\langle p_\perp^2 \rangle_{K^+ unfav}$ (GeV$^2$)"




        
        
        
global cnt
cnt=0
def plot(tags,name = None):
    global cnt
    for i in range(1,len(tags)):
        cnt+=1
        if tags[i]==None: continue
        idx=get_idx(tags[0],tags[i])
        ax=py.subplot(nrows,ncols,cnt)
        vmin=np.amin(samples2.T[idx])
        vmax=np.amax(samples2.T[idx])
        R=None#(vmin,vmax)
        for k in runs:
            ax.hist(runs[k]['samples'].T[idx],weights=runs[k]['weights'],bins=50,normed=True,range=R)
        ax.hist(samples.T[idx],weights=weights,bins=50,color='k',normed=True,range=R)
        ax.hist(samples2.T[idx],weights=weights2,bins=50,color='r',histtype='step',normed=True,range=R)
        #ax.set_title(tags[i])
        ax.set_title(title(tags,i))
        mean=np.einsum('i,i',samples2.T[idx],weights2)
        std=np.einsum('i,i',(samples2.T[idx]-mean)**2,weights2)**0.5
        print '%20s = %10.5f +/- %10.5f'%(tags[i],mean,std)
        #ax.set_xlim(vmin,vmax)
    py.tight_layout()
    if name: py.savefig(name)

plot(['pdf','widths0 valence','widths0 sea'],"kperp_hermes.pdf")
plot(['ff','widths0 pi+ fav','widths0 pi+ unfav'],"pperp_pi_hermes.pdf")
plot(['ff','widths0 k+ fav','widths0 k+ unfav'],"pperp_k_hermes.pdf")
# Out:
#      widths0 valence =    0.32327 +/-    0.02036
#          widths0 sea =    0.52986 +/-    0.06564
#      widths0 pi+ fav =    0.19523 +/-    0.00408
#    widths0 pi+ unfav =    0.17962 +/-    0.00383
#       widths0 k+ fav =    0.23353 +/-    0.00920
#     widths0 k+ unfav =    0.09569 +/-    0.01004

# %% [markdown]
# ## data vs theory

# %%
data={'weights':MC['weights2']}
cnt=0
for s in MC['samples2']:
    cnt+=1    
    lprint('%d/%d'%(cnt,len(MC['samples2'])))  
    conf['resman'].get_residuals(s);
    for k in conf['resman'].sidisres.tabs:
        if k  not in data: data[k]=[]
        thy=conf['resman'].sidisres.tabs[k]['thy']    
        norm=conf['datasets']['sidis']['norm'][k]['value']
        shift=conf['resman'].sidisres.tabs[k]['shift']        
        data[k].append(shift+thy/norm)
save(data,'%s/%s'%(path2results,'sidis.dat'))
# Out:
# 1549/1549

# %% [markdown]
# ### compute averages and collect results

# %%
data=load('%s/%s'%(path2results,'sidis.dat'))   
for k in data: data[k]=np.array(data[k])
thy,dthy={},{}
for k in data:
    if k=='weights': continue
    thy[k]=np.einsum('i,ik->k',data['weights'],data[k])
    dthy[k]=np.einsum('i,ik->k',data['weights'],(data[k]-thy[k])**2)**0.5
for k in thy: 
    conf['resman'].sidisres.tabs[k]['thy']=copy.copy(thy[k])
    conf['resman'].sidisres.tabs[k]['dthy']=copy.copy(dthy[k])

# %%
report=conf['resman'].gen_report(verb=0,level=1)
delimiters=[]
for i in range(len(report)): 
    if 'reaction:' in report[i]: delimiters.append(i) 

data={}
nlines=len(report)
for i in range(len(delimiters)):
    ini=delimiters[i]
    if i==len(delimiters)-1: fin=len(report)
    else: fin=delimiters[i+1]
    reaction=report[ini].replace('reaction:','').strip()
    data[reaction]={'raw data':report[ini:fin]}
    
for k in data:
    print k
    block=data[k]['raw data']
    isep=[i for i in range(len(block)) if '--------' in block[i]][0]
    data[k]['summary']=[block[i] for i in range(isep)]
    data[k]['tables']=[block[i] for i in range(isep+1,len(block))]

    tabs={}
    for l in data[k]['tables']:
        info=l.split(',')
        col=[s for s in info if 'col' in s][0].split('=')[1].strip()
        if col not in tabs: tabs[col]={}
        info=[[ss.strip() for ss in s.split('=')] for s in info if 'col' not in info  if s.strip()!='']
        
        for s in info:
            if s[0] not in tabs[col]: tabs[col][s[0]]=[]
        
        for s in info:
            try:
                value=float(s[1])
            except:
                value=s[1]
            tabs[col][s[0]].append(value)        

    data[k]['tabs']=tabs
save(data,'%s/%s'%(path2results,'data_and_thy.dat'))

# %%
def summary():
    for k in data:
        print ""
        for l in data[k]['summary']: print l
summary()

# %%
report
# Out:
# ['sidis',
#  u'   1000     proton        pi+     hermes   M_Hermes    45      77.39       0.00       0.00',
#  u'   1001     proton        pi-     hermes   M_Hermes    45      88.50       0.00       0.00',
#  u'   1002     proton         k+     hermes   M_Hermes    46      66.80       0.00       0.00',
#  u'   1003     proton         k-     hermes   M_Hermes    46      20.98       0.00       0.00',
#  u'   1004   deuteron        pi+     hermes   M_Hermes    45      59.56       0.00       0.00',
#  u'   1005   deuteron        pi-     hermes   M_Hermes    45      59.37       0.00       0.00',
#  u'   1006   deuteron         k+     hermes   M_Hermes    46      22.17       0.00       0.00',
#  u'   1007   deuteron         k-     hermes   M_Hermes    45      61.40       0.00       0.00',
#  '----------------------------------------------------------------------------------------------------',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.238e-01  pT= 1.015e-01  Q2= 1.821e+00  exp= 1.819e+00  alpha= 7.643e-02  thy= 1.736e+00  shift= 0.000e+00  chi2=     1.181  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.746e-01  pT= 1.019e-01  Q2= 1.821e+00  exp= 1.246e+00  alpha= 5.324e-02  thy= 1.228e+00  shift= 0.000e+00  chi2=     0.112  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 3.343e-01  pT= 1.004e-01  Q2= 1.821e+00  exp= 7.828e-01  alpha= 6.102e-02  thy= 8.131e-01  shift= 0.000e+00  chi2=    -0.246  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.195e-01  pT= 1.005e-01  Q2= 1.821e+00  exp= 4.349e-01  alpha= 4.404e-02  thy= 4.724e-01  shift= 0.000e+00  chi2=    -0.724  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.203e-01  pT= 2.037e-01  Q2= 1.821e+00  exp= 9.661e-01  alpha= 5.435e-02  thy= 8.507e-01  shift= 0.000e+00  chi2=     4.505  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.332e-01  pT= 1.029e-01  Q2= 1.821e+00  exp= 2.199e-01  alpha= 2.191e-02  thy= 2.443e-01  shift= 0.000e+00  chi2=    -1.241  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.315e-01  pT= 2.034e-01  Q2= 1.821e+00  exp= 4.743e-01  alpha= 3.465e-02  thy= 4.428e-01  shift= 0.000e+00  chi2=     0.831  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.233e-01  pT= 1.016e-01  Q2= 2.875e+00  exp= 1.847e+00  alpha= 1.126e-01  thy= 1.873e+00  shift= 0.000e+00  chi2=    -0.050  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.730e-01  pT= 1.020e-01  Q2= 2.875e+00  exp= 1.251e+00  alpha= 7.721e-02  thy= 1.319e+00  shift= 0.000e+00  chi2=    -0.762  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.346e-01  pT= 1.000e-01  Q2= 2.875e+00  exp= 7.799e-01  alpha= 4.836e-02  thy= 8.460e-01  shift= 0.000e+00  chi2=    -1.872  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.339e-01  pT= 2.029e-01  Q2= 2.875e+00  exp= 1.658e+00  alpha= 5.157e-02  thy= 1.523e+00  shift= 0.000e+00  chi2=     6.855  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.200e-01  pT= 1.001e-01  Q2= 2.875e+00  exp= 4.544e-01  alpha= 3.949e-02  thy= 4.827e-01  shift= 0.000e+00  chi2=    -0.515  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.198e-01  pT= 2.025e-01  Q2= 2.875e+00  exp= 9.222e-01  alpha= 3.675e-02  thy= 8.736e-01  shift= 0.000e+00  chi2=     1.747  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.307e-01  pT= 1.014e-01  Q2= 2.875e+00  exp= 2.120e-01  alpha= 1.884e-02  thy= 2.460e-01  shift= 0.000e+00  chi2=    -3.268  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.321e-01  pT= 2.022e-01  Q2= 2.875e+00  exp= 4.795e-01  alpha= 2.798e-02  thy= 4.409e-01  shift= 0.000e+00  chi2=     1.904  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.314e-01  pT= 3.019e-01  Q2= 2.875e+00  exp= 5.729e-01  alpha= 3.505e-02  thy= 5.565e-01  shift= 0.000e+00  chi2=     0.220  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.234e-01  pT= 1.020e-01  Q2= 5.241e+00  exp= 1.868e+00  alpha= 1.850e-01  thy= 1.981e+00  shift= 0.000e+00  chi2=    -0.373  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.736e-01  pT= 1.002e-01  Q2= 5.241e+00  exp= 1.265e+00  alpha= 8.750e-02  thy= 1.342e+00  shift= 0.000e+00  chi2=    -0.783  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.733e-01  pT= 2.031e-01  Q2= 5.241e+00  exp= 2.541e+00  alpha= 1.779e-01  thy= 2.388e+00  shift= 0.000e+00  chi2=     0.742  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.343e-01  pT= 9.973e-02  Q2= 5.241e+00  exp= 8.654e-01  alpha= 3.880e-02  thy= 8.656e-01  shift= 0.000e+00  chi2=    -0.000  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.344e-01  pT= 2.034e-01  Q2= 5.241e+00  exp= 1.677e+00  alpha= 1.079e-01  thy= 1.555e+00  shift= 0.000e+00  chi2=     1.283  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.197e-01  pT= 1.003e-01  Q2= 5.241e+00  exp= 4.474e-01  alpha= 1.838e-02  thy= 4.866e-01  shift= 0.000e+00  chi2=    -4.538  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.198e-01  pT= 2.030e-01  Q2= 5.241e+00  exp= 9.264e-01  alpha= 6.484e-02  thy= 8.776e-01  shift= 0.000e+00  chi2=     0.565  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.199e-01  pT= 3.025e-01  Q2= 5.241e+00  exp= 1.165e+00  alpha= 4.931e-02  thy= 1.076e+00  shift= 0.000e+00  chi2=     3.267  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.289e-01  pT= 1.012e-01  Q2= 5.241e+00  exp= 2.078e-01  alpha= 1.455e-02  thy= 2.435e-01  shift= 0.000e+00  chi2=    -6.020  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.318e-01  pT= 2.023e-01  Q2= 5.241e+00  exp= 4.588e-01  alpha= 3.337e-02  thy= 4.325e-01  shift= 0.000e+00  chi2=     0.618  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.299e-01  pT= 3.008e-01  Q2= 5.241e+00  exp= 5.610e-01  alpha= 5.379e-02  thy= 5.485e-01  shift= 0.000e+00  chi2=     0.055  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.311e-01  pT= 3.999e-01  Q2= 5.241e+00  exp= 5.539e-01  alpha= 3.402e-02  thy= 5.696e-01  shift= 0.000e+00  chi2=    -0.215  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.229e-01  pT= 1.005e-01  Q2= 9.213e+00  exp= 1.841e+00  alpha= 2.527e-01  thy= 2.007e+00  shift= 0.000e+00  chi2=    -0.431  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.240e-01  pT= 2.030e-01  Q2= 9.213e+00  exp= 4.136e+00  alpha= 4.367e-01  thy= 3.503e+00  shift= 0.000e+00  chi2=     2.099  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.753e-01  pT= 1.011e-01  Q2= 9.213e+00  exp= 1.349e+00  alpha= 1.684e-01  thy= 1.349e+00  shift= 0.000e+00  chi2=    -0.000  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.731e-01  pT= 2.059e-01  Q2= 9.213e+00  exp= 2.792e+00  alpha= 3.172e-01  thy= 2.437e+00  shift= 0.000e+00  chi2=     1.252  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.734e-01  pT= 3.022e-01  Q2= 9.213e+00  exp= 3.575e+00  alpha= 4.686e-01  thy= 2.880e+00  shift= 0.000e+00  chi2=     2.200  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.337e-01  pT= 1.083e-01  Q2= 9.213e+00  exp= 8.262e-01  alpha= 9.097e-02  thy= 9.371e-01  shift= 0.000e+00  chi2=    -1.486  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.358e-01  pT= 2.037e-01  Q2= 9.213e+00  exp= 1.663e+00  alpha= 1.853e-01  thy= 1.537e+00  shift= 0.000e+00  chi2=     0.457  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.369e-01  pT= 2.999e-01  Q2= 9.213e+00  exp= 2.102e+00  alpha= 2.126e-01  thy= 1.835e+00  shift= 0.000e+00  chi2=     1.576  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.220e-01  pT= 1.028e-01  Q2= 9.213e+00  exp= 3.497e-01  alpha= 5.397e-02  thy= 4.812e-01  shift= 0.000e+00  chi2=    -5.938  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.203e-01  pT= 2.019e-01  Q2= 9.213e+00  exp= 9.278e-01  alpha= 1.240e-01  thy= 8.556e-01  shift= 0.000e+00  chi2=     0.339  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.188e-01  pT= 3.044e-01  Q2= 9.213e+00  exp= 1.451e+00  alpha= 1.409e-01  thy= 1.065e+00  shift= 0.000e+00  chi2=     7.511  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.196e-01  pT= 3.990e-01  Q2= 9.213e+00  exp= 1.162e+00  alpha= 1.415e-01  thy= 1.073e+00  shift= 0.000e+00  chi2=     0.391  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.322e-01  pT= 9.885e-02  Q2= 9.213e+00  exp= 1.807e-01  alpha= 3.866e-02  thy= 2.244e-01  shift= 0.000e+00  chi2=    -1.279  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.319e-01  pT= 2.041e-01  Q2= 9.213e+00  exp= 5.976e-01  alpha= 8.929e-02  thy= 4.189e-01  shift= 0.000e+00  chi2=     4.007  ',
#  u'col= hermes  obs=M_Hermes  x= 4.100e-01  z= 5.319e-01  pT= 3.004e-01  Q2= 9.213e+00  exp= 5.858e-01  alpha= 1.021e-01  thy= 5.209e-01  shift= 0.000e+00  chi2=     0.405  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.296e-01  pT= 3.999e-01  Q2= 9.213e+00  exp= 6.863e-01  alpha= 1.031e-01  thy= 5.529e-01  shift= 0.000e+00  chi2=     1.672  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.335e-01  pT= 5.177e-01  Q2= 9.213e+00  exp= 5.720e-01  alpha= 6.683e-02  thy= 4.810e-01  shift= 0.000e+00  chi2=     1.851  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.232e-01  pT= 1.006e-01  Q2= 1.821e+00  exp= 1.364e+00  alpha= 2.050e-01  thy= 1.401e+00  shift= 0.000e+00  chi2=    -0.034  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.739e-01  pT= 1.000e-01  Q2= 1.821e+00  exp= 9.645e-01  alpha= 1.024e-01  thy= 9.193e-01  shift= 0.000e+00  chi2=     0.195  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 3.339e-01  pT= 1.013e-01  Q2= 1.821e+00  exp= 5.831e-01  alpha= 4.823e-02  thy= 5.842e-01  shift= 0.000e+00  chi2=    -0.001  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.204e-01  pT= 9.992e-02  Q2= 1.821e+00  exp= 3.061e-01  alpha= 3.528e-02  thy= 3.090e-01  shift= 0.000e+00  chi2=    -0.007  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.193e-01  pT= 2.035e-01  Q2= 1.821e+00  exp= 6.826e-01  alpha= 2.575e-02  thy= 5.637e-01  shift= 0.000e+00  chi2=    21.324  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.338e-01  pT= 1.014e-01  Q2= 1.821e+00  exp= 1.611e-01  alpha= 7.817e-03  thy= 1.448e-01  shift= 0.000e+00  chi2=     4.355  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.306e-01  pT= 2.028e-01  Q2= 1.821e+00  exp= 2.957e-01  alpha= 1.646e-02  thy= 2.678e-01  shift= 0.000e+00  chi2=     2.873  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.234e-01  pT= 1.020e-01  Q2= 2.875e+00  exp= 1.330e+00  alpha= 2.020e-01  thy= 1.484e+00  shift= 0.000e+00  chi2=    -0.584  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.730e-01  pT= 1.003e-01  Q2= 2.875e+00  exp= 9.470e-01  alpha= 1.070e-01  thy= 9.533e-01  shift= 0.000e+00  chi2=    -0.003  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.334e-01  pT= 1.022e-01  Q2= 2.875e+00  exp= 5.432e-01  alpha= 4.750e-02  thy= 5.951e-01  shift= 0.000e+00  chi2=    -1.192  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.339e-01  pT= 2.033e-01  Q2= 2.875e+00  exp= 1.140e+00  alpha= 7.246e-02  thy= 1.033e+00  shift= 0.000e+00  chi2=     2.192  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.208e-01  pT= 1.015e-01  Q2= 2.875e+00  exp= 2.891e-01  alpha= 3.426e-02  thy= 3.045e-01  shift= 0.000e+00  chi2=    -0.201  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.193e-01  pT= 2.025e-01  Q2= 2.875e+00  exp= 6.189e-01  alpha= 3.445e-02  thy= 5.462e-01  shift= 0.000e+00  chi2=     4.458  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.328e-01  pT= 1.011e-01  Q2= 2.875e+00  exp= 1.324e-01  alpha= 9.329e-03  thy= 1.350e-01  shift= 0.000e+00  chi2=    -0.075  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.301e-01  pT= 2.028e-01  Q2= 2.875e+00  exp= 2.979e-01  alpha= 2.357e-02  thy= 2.491e-01  shift= 0.000e+00  chi2=     4.293  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.307e-01  pT= 3.014e-01  Q2= 2.875e+00  exp= 3.721e-01  alpha= 1.002e-01  thy= 3.094e-01  shift= 0.000e+00  chi2=     0.393  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.236e-01  pT= 9.979e-02  Q2= 5.241e+00  exp= 1.404e+00  alpha= 1.289e-01  thy= 1.493e+00  shift= 0.000e+00  chi2=    -0.471  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.732e-01  pT= 1.008e-01  Q2= 5.241e+00  exp= 8.883e-01  alpha= 7.836e-02  thy= 9.621e-01  shift= 0.000e+00  chi2=    -0.887  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.732e-01  pT= 2.030e-01  Q2= 5.241e+00  exp= 1.779e+00  alpha= 4.961e-01  thy= 1.678e+00  shift= 0.000e+00  chi2=     0.041  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.337e-01  pT= 1.016e-01  Q2= 5.241e+00  exp= 4.361e-01  alpha= 3.796e-02  thy= 5.784e-01  shift= 0.000e+00  chi2=   -14.051  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.345e-01  pT= 2.029e-01  Q2= 5.241e+00  exp= 1.120e+00  alpha= 1.109e-01  thy= 1.004e+00  shift= 0.000e+00  chi2=     1.094  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.189e-01  pT= 1.025e-01  Q2= 5.241e+00  exp= 2.783e-01  alpha= 2.178e-02  thy= 2.947e-01  shift= 0.000e+00  chi2=    -0.568  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.179e-01  pT= 2.039e-01  Q2= 5.241e+00  exp= 5.460e-01  alpha= 6.945e-02  thy= 5.226e-01  shift= 0.000e+00  chi2=     0.114  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.193e-01  pT= 3.015e-01  Q2= 5.241e+00  exp= 7.115e-01  alpha= 1.585e-01  thy= 6.248e-01  shift= 0.000e+00  chi2=     0.299  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.293e-01  pT= 1.043e-01  Q2= 5.241e+00  exp= 1.212e-01  alpha= 1.027e-02  thy= 1.275e-01  shift= 0.000e+00  chi2=    -0.374  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.301e-01  pT= 2.015e-01  Q2= 5.241e+00  exp= 2.412e-01  alpha= 4.827e-02  thy= 2.214e-01  shift= 0.000e+00  chi2=     0.169  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.292e-01  pT= 3.016e-01  Q2= 5.241e+00  exp= 3.104e-01  alpha= 3.341e-02  thy= 2.782e-01  shift= 0.000e+00  chi2=     0.929  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.291e-01  pT= 3.989e-01  Q2= 5.241e+00  exp= 3.609e-01  alpha= 3.234e-02  thy= 2.879e-01  shift= 0.000e+00  chi2=     5.092  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.257e-01  pT= 1.021e-01  Q2= 9.213e+00  exp= 1.396e+00  alpha= 1.955e-01  thy= 1.495e+00  shift= 0.000e+00  chi2=    -0.257  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.243e-01  pT= 2.032e-01  Q2= 9.213e+00  exp= 3.102e+00  alpha= 8.245e-01  thy= 2.596e+00  shift= 0.000e+00  chi2=     0.377  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.711e-01  pT= 9.646e-02  Q2= 9.213e+00  exp= 6.814e-01  alpha= 1.244e-01  thy= 9.236e-01  shift= 0.000e+00  chi2=    -3.791  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.759e-01  pT= 2.049e-01  Q2= 9.213e+00  exp= 1.891e+00  alpha= 5.689e-01  thy= 1.614e+00  shift= 0.000e+00  chi2=     0.237  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.729e-01  pT= 3.027e-01  Q2= 9.213e+00  exp= 2.672e+00  alpha= 5.123e-01  thy= 1.937e+00  shift= 0.000e+00  chi2=     2.060  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.326e-01  pT= 1.030e-01  Q2= 9.213e+00  exp= 3.944e-01  alpha= 7.141e-02  thy= 5.682e-01  shift= 0.000e+00  chi2=    -5.922  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.338e-01  pT= 2.033e-01  Q2= 9.213e+00  exp= 1.164e+00  alpha= 1.713e-01  thy= 9.690e-01  shift= 0.000e+00  chi2=     1.299  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.337e-01  pT= 3.002e-01  Q2= 9.213e+00  exp= 1.424e+00  alpha= 3.159e-01  thy= 1.149e+00  shift= 0.000e+00  chi2=     0.759  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.191e-01  pT= 1.027e-01  Q2= 9.213e+00  exp= 2.498e-01  alpha= 4.523e-02  thy= 2.742e-01  shift= 0.000e+00  chi2=    -0.290  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.213e-01  pT= 2.034e-01  Q2= 9.213e+00  exp= 5.040e-01  alpha= 9.777e-02  thy= 4.720e-01  shift= 0.000e+00  chi2=     0.107  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.198e-01  pT= 3.040e-01  Q2= 9.213e+00  exp= 6.528e-01  alpha= 1.724e-01  thy= 5.779e-01  shift= 0.000e+00  chi2=     0.189  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.227e-01  pT= 3.963e-01  Q2= 9.213e+00  exp= 6.964e-01  alpha= 1.217e-01  thy= 5.641e-01  shift= 0.000e+00  chi2=     1.183  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.229e-01  pT= 1.011e-01  Q2= 9.213e+00  exp= 1.209e-01  alpha= 2.695e-02  thy= 1.158e-01  shift= 0.000e+00  chi2=     0.036  ',
#  u'col= hermes  obs=M_Hermes  x= 4.100e-01  z= 5.291e-01  pT= 2.005e-01  Q2= 9.213e+00  exp= 2.579e-01  alpha= 7.327e-02  thy= 1.970e-01  shift= 0.000e+00  chi2=     0.692  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.312e-01  pT= 3.028e-01  Q2= 9.213e+00  exp= 2.974e-01  alpha= 6.915e-02  thy= 2.422e-01  shift= 0.000e+00  chi2=     0.639  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.248e-01  pT= 4.022e-01  Q2= 9.213e+00  exp= 4.214e-01  alpha= 7.778e-02  thy= 2.616e-01  shift= 0.000e+00  chi2=     4.224  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.262e-01  pT= 5.220e-01  Q2= 9.213e+00  exp= 2.437e-01  alpha= 4.945e-02  thy= 2.236e-01  shift= 0.000e+00  chi2=     0.165  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.246e-01  pT= 1.012e-01  Q2= 1.821e+00  exp= 2.301e-01  alpha= 1.946e-02  thy= 2.301e-01  shift= 0.000e+00  chi2=    -0.000  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.758e-01  pT= 9.975e-02  Q2= 1.821e+00  exp= 2.023e-01  alpha= 4.047e-02  thy= 1.805e-01  shift= 0.000e+00  chi2=     0.292  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 3.363e-01  pT= 1.018e-01  Q2= 1.821e+00  exp= 1.479e-01  alpha= 4.257e-02  thy= 1.377e-01  shift= 0.000e+00  chi2=     0.057  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.200e-01  pT= 1.000e-01  Q2= 1.821e+00  exp= 9.302e-02  alpha= 2.455e-02  thy= 9.211e-02  shift= 0.000e+00  chi2=     0.001  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.214e-01  pT= 2.029e-01  Q2= 1.821e+00  exp= 1.923e-01  alpha= 5.080e-02  thy= 1.679e-01  shift= 0.000e+00  chi2=     0.230  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.295e-01  pT= 1.021e-01  Q2= 1.821e+00  exp= 4.615e-02  alpha= 3.080e-03  thy= 6.004e-02  shift= 0.000e+00  chi2=   -20.334  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.312e-01  pT= 2.040e-01  Q2= 1.821e+00  exp= 1.143e-01  alpha= 3.024e-02  thy= 1.088e-01  shift= 0.000e+00  chi2=     0.033  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.240e-01  pT= 1.005e-01  Q2= 2.875e+00  exp= 2.383e-01  alpha= 2.718e-02  thy= 2.300e-01  shift= 0.000e+00  chi2=     0.093  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.742e-01  pT= 9.928e-02  Q2= 2.875e+00  exp= 2.048e-01  alpha= 4.787e-02  thy= 1.819e-01  shift= 0.000e+00  chi2=     0.230  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.343e-01  pT= 1.012e-01  Q2= 2.875e+00  exp= 1.633e-01  alpha= 5.300e-02  thy= 1.395e-01  shift= 0.000e+00  chi2=     0.201  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.349e-01  pT= 2.028e-01  Q2= 2.875e+00  exp= 3.339e-01  alpha= 1.083e-01  thy= 2.496e-01  shift= 0.000e+00  chi2=     0.606  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.183e-01  pT= 9.922e-02  Q2= 2.875e+00  exp= 8.971e-02  alpha= 2.724e-02  thy= 9.358e-02  shift= 0.000e+00  chi2=    -0.020  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.211e-01  pT= 2.038e-01  Q2= 2.875e+00  exp= 1.990e-01  alpha= 6.040e-02  thy= 1.713e-01  shift= 0.000e+00  chi2=     0.211  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.312e-01  pT= 9.899e-02  Q2= 2.875e+00  exp= 4.934e-02  alpha= 3.900e-03  thy= 5.878e-02  shift= 0.000e+00  chi2=    -5.854  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.301e-01  pT= 2.029e-01  Q2= 2.875e+00  exp= 1.211e-01  alpha= 3.728e-02  thy= 1.103e-01  shift= 0.000e+00  chi2=     0.084  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.312e-01  pT= 3.016e-01  Q2= 2.875e+00  exp= 1.425e-01  alpha= 4.394e-02  thy= 1.397e-01  shift= 0.000e+00  chi2=     0.004  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.253e-01  pT= 1.027e-01  Q2= 5.241e+00  exp= 2.379e-01  alpha= 8.977e-02  thy= 2.390e-01  shift= 0.000e+00  chi2=    -0.000  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.249e-01  pT= 1.992e-01  Q2= 5.241e+00  exp= 4.996e-01  alpha= 7.358e-02  thy= 4.127e-01  shift= 0.000e+00  chi2=     1.394  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.721e-01  pT= 1.014e-01  Q2= 5.241e+00  exp= 2.616e-01  alpha= 6.509e-02  thy= 1.914e-01  shift= 0.000e+00  chi2=     1.163  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.747e-01  pT= 1.996e-01  Q2= 5.241e+00  exp= 3.737e-01  alpha= 4.334e-02  thy= 3.322e-01  shift= 0.000e+00  chi2=     0.913  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.342e-01  pT= 1.005e-01  Q2= 5.241e+00  exp= 1.790e-01  alpha= 2.836e-02  thy= 1.415e-01  shift= 0.000e+00  chi2=     1.750  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.357e-01  pT= 2.032e-01  Q2= 5.241e+00  exp= 3.369e-01  alpha= 5.458e-02  thy= 2.542e-01  shift= 0.000e+00  chi2=     2.293  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.215e-01  pT= 1.009e-01  Q2= 5.241e+00  exp= 9.408e-02  alpha= 1.689e-02  thy= 9.556e-02  shift= 0.000e+00  chi2=    -0.008  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.181e-01  pT= 2.046e-01  Q2= 5.241e+00  exp= 2.284e-01  alpha= 3.416e-02  thy= 1.773e-01  shift= 0.000e+00  chi2=     2.244  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.221e-01  pT= 3.005e-01  Q2= 5.241e+00  exp= 2.547e-01  alpha= 8.758e-02  thy= 2.163e-01  shift= 0.000e+00  chi2=     0.193  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.333e-01  pT= 9.986e-02  Q2= 5.241e+00  exp= 5.798e-02  alpha= 2.649e-02  thy= 5.909e-02  shift= 0.000e+00  chi2=    -0.002  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.330e-01  pT= 2.045e-01  Q2= 5.241e+00  exp= 1.459e-01  alpha= 2.701e-02  thy= 1.102e-01  shift= 0.000e+00  chi2=     1.742  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.339e-01  pT= 2.992e-01  Q2= 5.241e+00  exp= 1.636e-01  alpha= 1.760e-02  thy= 1.384e-01  shift= 0.000e+00  chi2=     2.057  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.337e-01  pT= 4.021e-01  Q2= 5.241e+00  exp= 1.638e-01  alpha= 3.959e-02  thy= 1.485e-01  shift= 0.000e+00  chi2=     0.150  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.259e-01  pT= 1.129e-01  Q2= 9.213e+00  exp= 7.281e-02  alpha= 7.432e-02  thy= 2.674e-01  shift= 0.000e+00  chi2=    -6.853  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.231e-01  pT= 2.071e-01  Q2= 9.213e+00  exp= 5.804e-01  alpha= 1.869e-01  thy= 4.393e-01  shift= 0.000e+00  chi2=     0.570  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.732e-01  pT= 1.029e-01  Q2= 9.213e+00  exp= 3.640e-01  alpha= 1.163e-01  thy= 1.967e-01  shift= 0.000e+00  chi2=     2.072  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.710e-01  pT= 1.974e-01  Q2= 9.213e+00  exp= 4.646e-01  alpha= 1.379e-01  thy= 3.427e-01  shift= 0.000e+00  chi2=     0.782  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.736e-01  pT= 2.981e-01  Q2= 9.213e+00  exp= 5.575e-01  alpha= 2.155e-01  thy= 4.198e-01  shift= 0.000e+00  chi2=     0.408  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.315e-01  pT= 1.047e-01  Q2= 9.213e+00  exp= 1.390e-01  alpha= 4.682e-02  thy= 1.511e-01  shift= 0.000e+00  chi2=    -0.066  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.359e-01  pT= 2.039e-01  Q2= 9.213e+00  exp= 4.263e-01  alpha= 1.041e-01  thy= 2.583e-01  shift= 0.000e+00  chi2=     2.607  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.319e-01  pT= 2.998e-01  Q2= 9.213e+00  exp= 3.990e-01  alpha= 1.745e-01  thy= 3.227e-01  shift= 0.000e+00  chi2=     0.191  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.334e-01  pT= 1.017e-01  Q2= 9.213e+00  exp= 1.249e-01  alpha= 3.658e-02  thy= 9.175e-02  shift= 0.000e+00  chi2=     0.822  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.233e-01  pT= 2.081e-01  Q2= 9.213e+00  exp= 2.489e-01  alpha= 6.857e-02  thy= 1.768e-01  shift= 0.000e+00  chi2=     1.108  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.201e-01  pT= 3.002e-01  Q2= 9.213e+00  exp= 3.687e-01  alpha= 1.451e-01  thy= 2.196e-01  shift= 0.000e+00  chi2=     1.055  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.161e-01  pT= 3.950e-01  Q2= 9.213e+00  exp= 2.975e-01  alpha= 1.243e-01  thy= 2.334e-01  shift= 0.000e+00  chi2=     0.266  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.323e-01  pT= 1.023e-01  Q2= 9.213e+00  exp= 1.390e-01  alpha= 6.855e-02  thy= 6.018e-02  shift= 0.000e+00  chi2=     1.323  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.315e-01  pT= 2.096e-01  Q2= 9.213e+00  exp= 2.048e-01  alpha= 6.062e-02  thy= 1.122e-01  shift= 0.000e+00  chi2=     2.334  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.342e-01  pT= 3.039e-01  Q2= 9.213e+00  exp= 1.624e-01  alpha= 5.712e-02  thy= 1.380e-01  shift= 0.000e+00  chi2=     0.183  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.348e-01  pT= 3.965e-01  Q2= 9.213e+00  exp= 2.333e-01  alpha= 7.519e-02  thy= 1.466e-01  shift= 0.000e+00  chi2=     1.329  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.241e-01  pT= 5.219e-01  Q2= 9.213e+00  exp= 6.690e-02  alpha= 4.495e-02  thy= 1.403e-01  shift= 0.000e+00  chi2=    -2.669  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.242e-01  pT= 1.020e-01  Q2= 1.821e+00  exp= 1.468e-01  alpha= 4.694e-02  thy= 1.653e-01  shift= 0.000e+00  chi2=    -0.156  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 2.745e-01  pT= 9.991e-02  Q2= 1.821e+00  exp= 9.633e-02  alpha= 4.049e-02  thy= 1.044e-01  shift= 0.000e+00  chi2=    -0.039  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 3.357e-01  pT= 1.007e-01  Q2= 1.821e+00  exp= 6.864e-02  alpha= 2.866e-02  thy= 6.179e-02  shift= 0.000e+00  chi2=     0.057  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.213e-01  pT= 1.012e-01  Q2= 1.821e+00  exp= 3.059e-02  alpha= 1.281e-02  thy= 3.238e-02  shift= 0.000e+00  chi2=    -0.019  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 4.227e-01  pT= 1.993e-01  Q2= 1.821e+00  exp= 6.281e-02  alpha= 2.626e-02  thy= 5.654e-02  shift= 0.000e+00  chi2=     0.057  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.312e-01  pT= 1.013e-01  Q2= 1.821e+00  exp= 1.821e-02  alpha= 7.684e-03  thy= 1.679e-02  shift= 0.000e+00  chi2=     0.034  ',
#  u'col= hermes  obs=M_Hermes  x= 9.574e-02  z= 5.324e-01  pT= 2.061e-01  Q2= 1.821e+00  exp= 3.976e-02  alpha= 1.667e-02  thy= 3.065e-02  shift= 0.000e+00  chi2=     0.299  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.238e-01  pT= 9.748e-02  Q2= 2.875e+00  exp= 1.200e-01  alpha= 5.080e-02  thy= 1.482e-01  shift= 0.000e+00  chi2=    -0.309  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 2.731e-01  pT= 1.012e-01  Q2= 2.875e+00  exp= 1.120e-01  alpha= 4.704e-02  thy= 9.515e-02  shift= 0.000e+00  chi2=     0.128  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.338e-01  pT= 1.006e-01  Q2= 2.875e+00  exp= 5.298e-02  alpha= 2.230e-02  thy= 5.364e-02  shift= 0.000e+00  chi2=    -0.001  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 3.341e-01  pT= 1.988e-01  Q2= 2.875e+00  exp= 1.131e-01  alpha= 4.741e-02  thy= 9.032e-02  shift= 0.000e+00  chi2=     0.230  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.164e-01  pT= 1.019e-01  Q2= 2.875e+00  exp= 2.648e-02  alpha= 1.121e-02  thy= 2.777e-02  shift= 0.000e+00  chi2=    -0.013  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 4.198e-01  pT= 2.094e-01  Q2= 2.875e+00  exp= 5.725e-02  alpha= 2.410e-02  thy= 4.799e-02  shift= 0.000e+00  chi2=     0.148  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.292e-01  pT= 1.017e-01  Q2= 2.875e+00  exp= 1.008e-02  alpha= 4.387e-03  thy= 1.346e-02  shift= 0.000e+00  chi2=    -0.594  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.261e-01  pT= 2.032e-01  Q2= 2.875e+00  exp= 2.777e-02  alpha= 1.179e-02  thy= 2.444e-02  shift= 0.000e+00  chi2=     0.080  ',
#  u'col= hermes  obs=M_Hermes  x= 1.522e-01  z= 5.282e-01  pT= 2.988e-01  Q2= 2.875e+00  exp= 3.123e-02  alpha= 1.339e-02  thy= 2.981e-02  shift= 0.000e+00  chi2=     0.011  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.214e-01  pT= 1.025e-01  Q2= 5.241e+00  exp= 1.049e-01  alpha= 4.607e-02  thy= 1.530e-01  shift= 0.000e+00  chi2=    -1.090  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.236e-01  pT= 1.975e-01  Q2= 5.241e+00  exp= 2.806e-01  alpha= 1.212e-01  thy= 2.338e-01  shift= 0.000e+00  chi2=     0.149  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.751e-01  pT= 1.038e-01  Q2= 5.241e+00  exp= 8.497e-02  alpha= 3.709e-02  thy= 8.860e-02  shift= 0.000e+00  chi2=    -0.010  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 2.710e-01  pT= 2.009e-01  Q2= 5.241e+00  exp= 2.045e-01  alpha= 8.780e-02  thy= 1.462e-01  shift= 0.000e+00  chi2=     0.441  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.318e-01  pT= 9.978e-02  Q2= 5.241e+00  exp= 5.023e-02  alpha= 2.173e-02  thy= 4.891e-02  shift= 0.000e+00  chi2=     0.004  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 3.334e-01  pT= 2.030e-01  Q2= 5.241e+00  exp= 9.780e-02  alpha= 4.226e-02  thy= 8.081e-02  shift= 0.000e+00  chi2=     0.162  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.158e-01  pT= 1.019e-01  Q2= 5.242e+00  exp= 2.075e-02  alpha= 9.360e-03  thy= 2.432e-02  shift= 0.000e+00  chi2=    -0.145  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.217e-01  pT= 2.002e-01  Q2= 5.241e+00  exp= 5.901e-02  alpha= 2.549e-02  thy= 3.910e-02  shift= 0.000e+00  chi2=     0.610  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 4.187e-01  pT= 3.027e-01  Q2= 5.241e+00  exp= 8.663e-02  alpha= 3.720e-02  thy= 4.606e-02  shift= 0.000e+00  chi2=     1.189  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.285e-01  pT= 9.009e-02  Q2= 5.241e+00  exp= 9.215e-03  alpha= 4.347e-03  thy= 9.980e-03  shift= 0.000e+00  chi2=    -0.031  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.334e-01  pT= 2.077e-01  Q2= 5.241e+00  exp= 2.745e-02  alpha= 1.221e-02  thy= 1.907e-02  shift= 0.000e+00  chi2=     0.471  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.303e-01  pT= 3.089e-01  Q2= 5.241e+00  exp= 1.989e-02  alpha= 9.580e-03  thy= 2.310e-02  shift= 0.000e+00  chi2=    -0.113  ',
#  u'col= hermes  obs=M_Hermes  x= 2.539e-01  z= 5.324e-01  pT= 4.008e-01  Q2= 5.241e+00  exp= 4.049e-02  alpha= 1.795e-02  thy= 2.247e-02  shift= 0.000e+00  chi2=     1.006  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.247e-01  pT= 8.471e-02  Q2= 9.213e+00  exp= 1.377e-01  alpha= 8.166e-02  thy= 1.255e-01  shift= 0.000e+00  chi2=     0.022  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.261e-01  pT= 1.934e-01  Q2= 9.213e+00  exp= 3.464e-01  alpha= 1.827e-01  thy= 2.246e-01  shift= 0.000e+00  chi2=     0.445  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.738e-01  pT= 9.710e-02  Q2= 9.213e+00  exp= 6.569e-02  alpha= 4.333e-02  thy= 8.367e-02  shift= 0.000e+00  chi2=    -0.172  ',
#  u'col= hermes  obs=M_Hermes  x= 4.100e-01  z= 2.739e-01  pT= 1.980e-01  Q2= 9.213e+00  exp= 4.052e-02  alpha= 6.617e-02  thy= 1.376e-01  shift= 0.000e+00  chi2=    -2.154  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 2.702e-01  pT= 2.972e-01  Q2= 9.213e+00  exp= 3.888e-01  alpha= 1.957e-01  thy= 1.512e-01  shift= 0.000e+00  chi2=     1.474  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.423e-01  pT= 1.011e-01  Q2= 9.213e+00  exp= 5.348e-02  alpha= 3.204e-02  thy= 4.369e-02  shift= 0.000e+00  chi2=     0.093  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 3.325e-01  pT= 1.943e-01  Q2= 9.213e+00  exp= 2.634e-01  alpha= 1.236e-01  thy= 7.684e-02  shift= 0.000e+00  chi2=     2.278  ',
#  u'col= hermes  obs=M_Hermes  x= 4.105e-01  z= 3.411e-01  pT= 3.138e-01  Q2= 9.217e+00  exp= 3.765e-01  alpha= 2.829e-01  thy= 7.746e-02  shift= 0.000e+00  chi2=     1.117  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.160e-01  pT= 1.031e-01  Q2= 9.213e+00  exp= 1.670e-02  alpha= 1.360e-02  thy= 2.359e-02  shift= 0.000e+00  chi2=    -0.256  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.008e-01  pT= 2.065e-01  Q2= 9.209e+00  exp= 7.049e-02  alpha= 4.755e-02  thy= 4.383e-02  shift= 0.000e+00  chi2=     0.314  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.310e-01  pT= 3.122e-01  Q2= 9.213e+00  exp= 1.080e-01  alpha= 6.036e-02  thy= 3.896e-02  shift= 0.000e+00  chi2=     1.309  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 4.059e-01  pT= 4.036e-01  Q2= 9.213e+00  exp= 6.711e-02  alpha= 4.423e-02  thy= 4.109e-02  shift= 0.000e+00  chi2=     0.346  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.463e-01  pT= 1.259e-01  Q2= 9.213e+00  exp= 2.235e-02  alpha= 1.540e-02  thy= 1.083e-02  shift= 0.000e+00  chi2=     0.560  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.401e-01  pT= 2.080e-01  Q2= 9.218e+00  exp= 5.654e-02  alpha= 3.830e-02  thy= 1.648e-02  shift= 0.000e+00  chi2=     1.094  ',
#  u'col= hermes  obs=M_Hermes  x= 4.100e-01  z= 5.268e-01  pT= 3.178e-01  Q2= 9.213e+00  exp= 4.097e-02  alpha= 2.709e-02  thy= 2.098e-02  shift= 0.000e+00  chi2=     0.544  ',
#  u'col= hermes  obs=M_Hermes  x= 4.101e-01  z= 5.257e-01  pT= 3.973e-01  Q2= 9.213e+00  exp= 5.143e-02  alpha= 3.033e-02  thy= 2.015e-02  shift= 0.000e+00  chi2=     1.064  ',
#  u'col= hermes  obs=M_Hermes  x= 4.100e-01  z= 5.147e-01  pT= 5.059e-01  Q2= 9.213e+00  exp= 2.380e-02  alpha= 1.803e-02  thy= 1.710e-02  shift= 0.000e+00  chi2=     0.138  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.236e-01  pT= 1.002e-01  Q2= 1.835e+00  exp= 1.682e+00  alpha= 2.129e-01  thy= 1.663e+00  shift= 0.000e+00  chi2=     0.008  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.736e-01  pT= 1.016e-01  Q2= 1.835e+00  exp= 1.153e+00  alpha= 9.987e-02  thy= 1.185e+00  shift= 0.000e+00  chi2=    -0.103  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 3.349e-01  pT= 1.013e-01  Q2= 1.835e+00  exp= 7.455e-01  alpha= 4.135e-02  thy= 7.784e-01  shift= 0.000e+00  chi2=    -0.636  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.200e-01  pT= 1.009e-01  Q2= 1.835e+00  exp= 4.122e-01  alpha= 1.613e-02  thy= 4.471e-01  shift= 0.000e+00  chi2=    -4.672  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.204e-01  pT= 2.031e-01  Q2= 1.835e+00  exp= 8.689e-01  alpha= 7.170e-02  thy= 8.018e-01  shift= 0.000e+00  chi2=     0.876  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.311e-01  pT= 1.023e-01  Q2= 1.835e+00  exp= 2.093e-01  alpha= 1.406e-02  thy= 2.307e-01  shift= 0.000e+00  chi2=    -2.311  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.312e-01  pT= 2.024e-01  Q2= 1.835e+00  exp= 4.350e-01  alpha= 4.804e-02  thy= 4.138e-01  shift= 0.000e+00  chi2=     0.196  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.235e-01  pT= 1.011e-01  Q2= 2.882e+00  exp= 1.704e+00  alpha= 3.007e-01  thy= 1.798e+00  shift= 0.000e+00  chi2=    -0.099  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.735e-01  pT= 1.011e-01  Q2= 2.882e+00  exp= 1.190e+00  alpha= 1.571e-01  thy= 1.248e+00  shift= 0.000e+00  chi2=    -0.135  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.346e-01  pT= 1.012e-01  Q2= 2.882e+00  exp= 7.271e-01  alpha= 6.668e-02  thy= 8.123e-01  shift= 0.000e+00  chi2=    -1.632  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.347e-01  pT= 2.032e-01  Q2= 2.882e+00  exp= 1.644e+00  alpha= 1.000e-01  thy= 1.439e+00  shift= 0.000e+00  chi2=     4.199  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.195e-01  pT= 1.004e-01  Q2= 2.882e+00  exp= 4.218e-01  alpha= 2.535e-02  thy= 4.570e-01  shift= 0.000e+00  chi2=    -1.925  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.200e-01  pT= 2.028e-01  Q2= 2.882e+00  exp= 8.738e-01  alpha= 3.041e-02  thy= 8.215e-01  shift= 0.000e+00  chi2=     2.961  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.301e-01  pT= 1.007e-01  Q2= 2.882e+00  exp= 2.171e-01  alpha= 9.087e-03  thy= 2.283e-01  shift= 0.000e+00  chi2=    -1.509  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.303e-01  pT= 2.032e-01  Q2= 2.882e+00  exp= 4.656e-01  alpha= 2.963e-02  thy= 4.164e-01  shift= 0.000e+00  chi2=     2.762  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.316e-01  pT= 3.009e-01  Q2= 2.882e+00  exp= 5.377e-01  alpha= 4.818e-02  thy= 5.164e-01  shift= 0.000e+00  chi2=     0.194  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.238e-01  pT= 1.021e-01  Q2= 5.223e+00  exp= 1.591e+00  alpha= 3.503e-01  thy= 1.907e+00  shift= 0.000e+00  chi2=    -0.815  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.738e-01  pT= 1.026e-01  Q2= 5.223e+00  exp= 1.237e+00  alpha= 2.192e-01  thy= 1.311e+00  shift= 0.000e+00  chi2=    -0.114  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.731e-01  pT= 2.027e-01  Q2= 5.223e+00  exp= 2.538e+00  alpha= 3.181e-01  thy= 2.282e+00  shift= 0.000e+00  chi2=     0.646  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.328e-01  pT= 1.021e-01  Q2= 5.223e+00  exp= 7.926e-01  alpha= 1.062e-01  thy= 8.475e-01  shift= 0.000e+00  chi2=    -0.268  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.335e-01  pT= 2.028e-01  Q2= 5.223e+00  exp= 1.591e+00  alpha= 1.338e-01  thy= 1.480e+00  shift= 0.000e+00  chi2=     0.694  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.193e-01  pT= 1.003e-01  Q2= 5.223e+00  exp= 4.278e-01  alpha= 3.836e-02  thy= 4.578e-01  shift= 0.000e+00  chi2=    -0.610  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.189e-01  pT= 2.037e-01  Q2= 5.223e+00  exp= 9.062e-01  alpha= 4.534e-02  thy= 8.308e-01  shift= 0.000e+00  chi2=     2.762  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.195e-01  pT= 3.004e-01  Q2= 5.223e+00  exp= 1.073e+00  alpha= 5.282e-02  thy= 1.010e+00  shift= 0.000e+00  chi2=     1.441  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.331e-01  pT= 1.010e-01  Q2= 5.223e+00  exp= 1.877e-01  alpha= 1.427e-02  thy= 2.192e-01  shift= 0.000e+00  chi2=    -4.874  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.304e-01  pT= 2.030e-01  Q2= 5.223e+00  exp= 4.406e-01  alpha= 2.463e-02  thy= 4.057e-01  shift= 0.000e+00  chi2=     2.005  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.306e-01  pT= 3.013e-01  Q2= 5.223e+00  exp= 5.218e-01  alpha= 3.507e-02  thy= 5.066e-01  shift= 0.000e+00  chi2=     0.186  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.294e-01  pT= 4.009e-01  Q2= 5.223e+00  exp= 5.310e-01  alpha= 3.878e-02  thy= 5.332e-01  shift= 0.000e+00  chi2=    -0.003  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.238e-01  pT= 1.015e-01  Q2= 9.202e+00  exp= 1.334e+00  alpha= 3.316e-01  thy= 1.934e+00  shift= 0.000e+00  chi2=    -3.272  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.245e-01  pT= 2.043e-01  Q2= 9.202e+00  exp= 3.588e+00  alpha= 6.768e-01  thy= 3.363e+00  shift= 0.000e+00  chi2=     0.110  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.737e-01  pT= 1.054e-01  Q2= 9.202e+00  exp= 1.088e+00  alpha= 2.305e-01  thy= 1.352e+00  shift= 0.000e+00  chi2=    -1.312  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.733e-01  pT= 2.037e-01  Q2= 9.202e+00  exp= 2.901e+00  alpha= 4.402e-01  thy= 2.298e+00  shift= 0.000e+00  chi2=     1.877  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.743e-01  pT= 3.005e-01  Q2= 9.202e+00  exp= 3.145e+00  alpha= 4.372e-01  thy= 2.712e+00  shift= 0.000e+00  chi2=     0.984  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.328e-01  pT= 1.007e-01  Q2= 9.202e+00  exp= 8.320e-01  alpha= 1.394e-01  thy= 8.307e-01  shift= 0.000e+00  chi2=     0.000  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.341e-01  pT= 2.035e-01  Q2= 9.202e+00  exp= 1.451e+00  alpha= 1.906e-01  thy= 1.465e+00  shift= 0.000e+00  chi2=    -0.005  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.347e-01  pT= 2.995e-01  Q2= 9.202e+00  exp= 2.097e+00  alpha= 2.237e-01  thy= 1.752e+00  shift= 0.000e+00  chi2=     2.380  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.178e-01  pT= 9.824e-02  Q2= 9.202e+00  exp= 3.318e-01  alpha= 6.003e-02  thy= 4.426e-01  shift= 0.000e+00  chi2=    -3.410  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.175e-01  pT= 2.024e-01  Q2= 9.202e+00  exp= 9.493e-01  alpha= 1.134e-01  thy= 8.143e-01  shift= 0.000e+00  chi2=     1.418  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.184e-01  pT= 3.004e-01  Q2= 9.202e+00  exp= 1.118e+00  alpha= 1.319e-01  thy= 9.905e-01  shift= 0.000e+00  chi2=     0.935  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.198e-01  pT= 4.001e-01  Q2= 9.202e+00  exp= 1.026e+00  alpha= 1.393e-01  thy= 9.961e-01  shift= 0.000e+00  chi2=     0.047  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.275e-01  pT= 1.058e-01  Q2= 9.202e+00  exp= 2.084e-01  alpha= 3.965e-02  thy= 2.270e-01  shift= 0.000e+00  chi2=    -0.219  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.269e-01  pT= 2.058e-01  Q2= 9.202e+00  exp= 4.354e-01  alpha= 7.536e-02  thy= 4.002e-01  shift= 0.000e+00  chi2=     0.218  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.317e-01  pT= 3.008e-01  Q2= 9.202e+00  exp= 5.940e-01  alpha= 9.656e-02  thy= 4.795e-01  shift= 0.000e+00  chi2=     1.407  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.322e-01  pT= 4.009e-01  Q2= 9.202e+00  exp= 6.487e-01  alpha= 1.019e-01  thy= 4.991e-01  shift= 0.000e+00  chi2=     2.155  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.320e-01  pT= 5.225e-01  Q2= 9.202e+00  exp= 5.138e-01  alpha= 6.676e-02  thy= 4.412e-01  shift= 0.000e+00  chi2=     1.181  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.236e-01  pT= 1.015e-01  Q2= 1.835e+00  exp= 1.569e+00  alpha= 3.881e-01  thy= 1.466e+00  shift= 0.000e+00  chi2=     0.071  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.731e-01  pT= 1.001e-01  Q2= 1.835e+00  exp= 1.053e+00  alpha= 4.587e-02  thy= 9.734e-01  shift= 0.000e+00  chi2=     2.996  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 3.350e-01  pT= 1.028e-01  Q2= 1.835e+00  exp= 5.894e-01  alpha= 2.184e-02  thy= 6.243e-01  shift= 0.000e+00  chi2=    -2.546  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.197e-01  pT= 1.016e-01  Q2= 1.835e+00  exp= 3.250e-01  alpha= 1.036e-02  thy= 3.389e-01  shift= 0.000e+00  chi2=    -1.794  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.212e-01  pT= 2.036e-01  Q2= 1.835e+00  exp= 6.649e-01  alpha= 1.717e-01  thy= 5.995e-01  shift= 0.000e+00  chi2=     0.145  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.311e-01  pT= 1.008e-01  Q2= 1.835e+00  exp= 1.554e-01  alpha= 1.204e-02  thy= 1.602e-01  shift= 0.000e+00  chi2=    -0.155  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.305e-01  pT= 2.015e-01  Q2= 1.835e+00  exp= 3.562e-01  alpha= 7.358e-02  thy= 2.916e-01  shift= 0.000e+00  chi2=     0.772  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.233e-01  pT= 1.009e-01  Q2= 2.882e+00  exp= 1.447e+00  alpha= 3.301e-01  thy= 1.540e+00  shift= 0.000e+00  chi2=    -0.080  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.736e-01  pT= 1.004e-01  Q2= 2.882e+00  exp= 9.744e-01  alpha= 2.677e-01  thy= 1.008e+00  shift= 0.000e+00  chi2=    -0.016  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.344e-01  pT= 1.012e-01  Q2= 2.882e+00  exp= 6.212e-01  alpha= 1.976e-02  thy= 6.282e-01  shift= 0.000e+00  chi2=    -0.124  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.347e-01  pT= 2.034e-01  Q2= 2.882e+00  exp= 1.304e+00  alpha= 3.017e-01  thy= 1.106e+00  shift= 0.000e+00  chi2=     0.431  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.196e-01  pT= 1.019e-01  Q2= 2.882e+00  exp= 3.121e-01  alpha= 9.963e-03  thy= 3.367e-01  shift= 0.000e+00  chi2=    -6.095  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.200e-01  pT= 2.024e-01  Q2= 2.882e+00  exp= 6.847e-01  alpha= 1.692e-01  thy= 5.944e-01  shift= 0.000e+00  chi2=     0.285  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.308e-01  pT= 9.975e-02  Q2= 2.882e+00  exp= 1.501e-01  alpha= 4.284e-02  thy= 1.510e-01  shift= 0.000e+00  chi2=    -0.001  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.300e-01  pT= 2.037e-01  Q2= 2.882e+00  exp= 3.215e-01  alpha= 6.902e-02  thy= 2.797e-01  shift= 0.000e+00  chi2=     0.368  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.308e-01  pT= 2.999e-01  Q2= 2.882e+00  exp= 4.373e-01  alpha= 6.963e-02  thy= 3.462e-01  shift= 0.000e+00  chi2=     1.714  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.234e-01  pT= 1.020e-01  Q2= 5.223e+00  exp= 1.485e+00  alpha= 1.368e-01  thy= 1.612e+00  shift= 0.000e+00  chi2=    -0.861  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.728e-01  pT= 1.004e-01  Q2= 5.223e+00  exp= 9.358e-01  alpha= 1.236e-01  thy= 1.030e+00  shift= 0.000e+00  chi2=    -0.586  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.731e-01  pT= 2.024e-01  Q2= 5.223e+00  exp= 2.072e+00  alpha= 1.337e-01  thy= 1.803e+00  shift= 0.000e+00  chi2=     4.056  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.342e-01  pT= 9.986e-02  Q2= 5.223e+00  exp= 5.763e-01  alpha= 9.706e-02  thy= 6.177e-01  shift= 0.000e+00  chi2=    -0.182  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.340e-01  pT= 2.029e-01  Q2= 5.223e+00  exp= 1.132e+00  alpha= 1.078e-01  thy= 1.101e+00  shift= 0.000e+00  chi2=     0.085  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.198e-01  pT= 9.967e-02  Q2= 5.223e+00  exp= 2.842e-01  alpha= 5.361e-02  thy= 3.175e-01  shift= 0.000e+00  chi2=    -0.386  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.206e-01  pT= 2.027e-01  Q2= 5.223e+00  exp= 5.859e-01  alpha= 6.395e-02  thy= 5.695e-01  shift= 0.000e+00  chi2=     0.066  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.187e-01  pT= 3.005e-01  Q2= 5.223e+00  exp= 7.776e-01  alpha= 4.937e-02  thy= 7.024e-01  shift= 0.000e+00  chi2=     2.324  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.326e-01  pT= 1.018e-01  Q2= 5.223e+00  exp= 1.362e-01  alpha= 2.104e-02  thy= 1.401e-01  shift= 0.000e+00  chi2=    -0.035  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.276e-01  pT= 2.038e-01  Q2= 5.223e+00  exp= 2.975e-01  alpha= 2.494e-02  thy= 2.625e-01  shift= 0.000e+00  chi2=     1.964  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.299e-01  pT= 3.019e-01  Q2= 5.223e+00  exp= 3.337e-01  alpha= 2.466e-02  thy= 3.206e-01  shift= 0.000e+00  chi2=     0.279  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.295e-01  pT= 3.996e-01  Q2= 5.223e+00  exp= 3.842e-01  alpha= 3.761e-02  thy= 3.337e-01  shift= 0.000e+00  chi2=     1.803  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.236e-01  pT= 1.023e-01  Q2= 9.202e+00  exp= 1.325e+00  alpha= 1.866e-01  thy= 1.629e+00  shift= 0.000e+00  chi2=    -2.643  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.240e-01  pT= 2.065e-01  Q2= 9.202e+00  exp= 3.060e+00  alpha= 2.968e-01  thy= 2.808e+00  shift= 0.000e+00  chi2=     0.721  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.725e-01  pT= 9.819e-02  Q2= 9.202e+00  exp= 9.393e-01  alpha= 1.703e-01  thy= 1.006e+00  shift= 0.000e+00  chi2=    -0.151  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.749e-01  pT= 2.058e-01  Q2= 9.202e+00  exp= 1.871e+00  alpha= 2.300e-01  thy= 1.778e+00  shift= 0.000e+00  chi2=     0.163  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.739e-01  pT= 3.035e-01  Q2= 9.202e+00  exp= 3.315e+00  alpha= 3.210e-01  thy= 2.097e+00  shift= 0.000e+00  chi2=    14.380  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.341e-01  pT= 9.765e-02  Q2= 9.202e+00  exp= 5.519e-01  alpha= 1.162e-01  thy= 5.906e-01  shift= 0.000e+00  chi2=    -0.111  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.308e-01  pT= 2.045e-01  Q2= 9.202e+00  exp= 1.151e+00  alpha= 1.702e-01  thy= 1.107e+00  shift= 0.000e+00  chi2=     0.067  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.336e-01  pT= 2.987e-01  Q2= 9.202e+00  exp= 1.508e+00  alpha= 1.704e-01  thy= 1.281e+00  shift= 0.000e+00  chi2=     1.785  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 4.206e-01  pT= 9.967e-02  Q2= 9.206e+00  exp= 2.502e-01  alpha= 6.517e-02  thy= 3.004e-01  shift= 0.000e+00  chi2=    -0.592  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.174e-01  pT= 2.064e-01  Q2= 9.202e+00  exp= 5.741e-01  alpha= 1.036e-01  thy= 5.619e-01  shift= 0.000e+00  chi2=     0.014  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.175e-01  pT= 3.000e-01  Q2= 9.202e+00  exp= 7.740e-01  alpha= 1.060e-01  thy= 6.722e-01  shift= 0.000e+00  chi2=     0.921  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.197e-01  pT= 3.996e-01  Q2= 9.202e+00  exp= 7.608e-01  alpha= 1.130e-01  thy= 6.632e-01  shift= 0.000e+00  chi2=     0.744  ',
# ...
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.759e-01  pT= 9.871e-02  Q2= 1.835e+00  exp= 2.275e-01  alpha= 6.970e-02  thy= 1.710e-01  shift= 0.000e+00  chi2=     0.658  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 3.345e-01  pT= 1.004e-01  Q2= 1.835e+00  exp= 1.345e-01  alpha= 2.675e-02  thy= 1.292e-01  shift= 0.000e+00  chi2=     0.039  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.203e-01  pT= 1.014e-01  Q2= 1.835e+00  exp= 7.768e-02  alpha= 1.337e-02  thy= 8.658e-02  shift= 0.000e+00  chi2=    -0.443  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.227e-01  pT= 2.016e-01  Q2= 1.835e+00  exp= 1.800e-01  alpha= 7.801e-02  thy= 1.542e-01  shift= 0.000e+00  chi2=     0.109  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.300e-01  pT= 1.015e-01  Q2= 1.835e+00  exp= 5.084e-02  alpha= 1.769e-02  thy= 5.483e-02  shift= 0.000e+00  chi2=    -0.051  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.332e-01  pT= 2.034e-01  Q2= 1.835e+00  exp= 1.094e-01  alpha= 3.065e-02  thy= 9.896e-02  shift= 0.000e+00  chi2=     0.116  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.254e-01  pT= 1.013e-01  Q2= 2.882e+00  exp= 2.561e-01  alpha= 1.179e-01  thy= 2.224e-01  shift= 0.000e+00  chi2=     0.082  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.744e-01  pT= 9.968e-02  Q2= 2.882e+00  exp= 2.203e-01  alpha= 7.448e-02  thy= 1.726e-01  shift= 0.000e+00  chi2=     0.411  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.357e-01  pT= 9.977e-02  Q2= 2.882e+00  exp= 1.424e-01  alpha= 3.370e-02  thy= 1.272e-01  shift= 0.000e+00  chi2=     0.204  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.353e-01  pT= 2.021e-01  Q2= 2.882e+00  exp= 2.991e-01  alpha= 1.211e-01  thy= 2.307e-01  shift= 0.000e+00  chi2=     0.319  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.184e-01  pT= 9.828e-02  Q2= 2.882e+00  exp= 8.274e-02  alpha= 1.867e-02  thy= 8.505e-02  shift= 0.000e+00  chi2=    -0.015  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.215e-01  pT= 2.020e-01  Q2= 2.882e+00  exp= 1.913e-01  alpha= 8.127e-02  thy= 1.556e-01  shift= 0.000e+00  chi2=     0.194  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.296e-01  pT= 1.027e-01  Q2= 2.882e+00  exp= 4.984e-02  alpha= 1.866e-02  thy= 5.552e-02  shift= 0.000e+00  chi2=    -0.092  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.329e-01  pT= 2.024e-01  Q2= 2.882e+00  exp= 1.143e-01  alpha= 2.647e-02  thy= 9.865e-02  shift= 0.000e+00  chi2=     0.351  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.327e-01  pT= 2.985e-01  Q2= 2.882e+00  exp= 1.395e-01  alpha= 3.230e-02  thy= 1.253e-01  shift= 0.000e+00  chi2=     0.193  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.253e-01  pT= 1.002e-01  Q2= 5.223e+00  exp= 2.531e-01  alpha= 3.068e-02  thy= 2.234e-01  shift= 0.000e+00  chi2=     0.932  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.733e-01  pT= 9.532e-02  Q2= 5.223e+00  exp= 2.507e-01  alpha= 6.991e-02  thy= 1.682e-01  shift= 0.000e+00  chi2=     1.391  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.731e-01  pT= 2.007e-01  Q2= 5.223e+00  exp= 3.226e-01  alpha= 1.020e-01  thy= 3.133e-01  shift= 0.000e+00  chi2=     0.008  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.359e-01  pT= 1.000e-01  Q2= 5.223e+00  exp= 1.694e-01  alpha= 6.149e-02  thy= 1.286e-01  shift= 0.000e+00  chi2=     0.441  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.338e-01  pT= 2.021e-01  Q2= 5.223e+00  exp= 3.063e-01  alpha= 6.165e-02  thy= 2.344e-01  shift= 0.000e+00  chi2=     1.363  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.207e-01  pT= 1.014e-01  Q2= 5.223e+00  exp= 1.006e-01  alpha= 4.741e-02  thy= 8.743e-02  shift= 0.000e+00  chi2=     0.077  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.202e-01  pT= 2.031e-01  Q2= 5.223e+00  exp= 1.917e-01  alpha= 3.366e-02  thy= 1.583e-01  shift= 0.000e+00  chi2=     0.985  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.208e-01  pT= 3.016e-01  Q2= 5.223e+00  exp= 2.329e-01  alpha= 6.949e-02  thy= 1.967e-01  shift= 0.000e+00  chi2=     0.271  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.265e-01  pT= 1.034e-01  Q2= 5.223e+00  exp= 5.383e-02  alpha= 2.757e-02  thy= 5.654e-02  shift= 0.000e+00  chi2=    -0.010  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.328e-01  pT= 2.035e-01  Q2= 5.223e+00  exp= 1.296e-01  alpha= 4.266e-02  thy= 9.872e-02  shift= 0.000e+00  chi2=     0.525  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.328e-01  pT= 3.006e-01  Q2= 5.223e+00  exp= 1.672e-01  alpha= 4.672e-02  thy= 1.250e-01  shift= 0.000e+00  chi2=     0.815  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.328e-01  pT= 3.978e-01  Q2= 5.223e+00  exp= 1.603e-01  alpha= 5.017e-02  thy= 1.336e-01  shift= 0.000e+00  chi2=     0.283  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.190e-01  pT= 9.720e-02  Q2= 9.202e+00  exp= 1.112e-01  alpha= 7.782e-02  thy= 2.280e-01  shift= 0.000e+00  chi2=    -2.251  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.238e-01  pT= 2.030e-01  Q2= 9.202e+00  exp= 8.121e-01  alpha= 3.928e-01  thy= 4.059e-01  shift= 0.000e+00  chi2=     1.069  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.767e-01  pT= 1.040e-01  Q2= 9.202e+00  exp= 2.334e-01  alpha= 9.387e-02  thy= 1.808e-01  shift= 0.000e+00  chi2=     0.314  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.778e-01  pT= 2.085e-01  Q2= 9.202e+00  exp= 3.182e-01  alpha= 1.486e-01  thy= 3.166e-01  shift= 0.000e+00  chi2=     0.000  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 2.759e-01  pT= 2.954e-01  Q2= 9.206e+00  exp= 5.338e-01  alpha= 1.739e-01  thy= 3.779e-01  shift= 0.000e+00  chi2=     0.803  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.362e-01  pT= 9.801e-02  Q2= 9.202e+00  exp= 1.879e-01  alpha= 8.114e-02  thy= 1.262e-01  shift= 0.000e+00  chi2=     0.578  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.327e-01  pT= 2.024e-01  Q2= 9.202e+00  exp= 2.872e-01  alpha= 9.525e-02  thy= 2.363e-01  shift= 0.000e+00  chi2=     0.285  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 3.361e-01  pT= 2.981e-01  Q2= 9.206e+00  exp= 4.372e-01  alpha= 1.528e-01  thy= 2.845e-01  shift= 0.000e+00  chi2=     0.998  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.417e-01  pT= 3.967e-01  Q2= 9.202e+00  exp= 3.843e-01  alpha= 1.468e-01  thy= 2.838e-01  shift= 0.000e+00  chi2=     0.468  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.206e-01  pT= 1.072e-01  Q2= 9.202e+00  exp= 1.381e-01  alpha= 7.180e-02  thy= 9.163e-02  shift= 0.000e+00  chi2=     0.418  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.231e-01  pT= 2.016e-01  Q2= 9.202e+00  exp= 2.364e-01  alpha= 6.716e-02  thy= 1.546e-01  shift= 0.000e+00  chi2=     1.483  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.231e-01  pT= 2.999e-01  Q2= 9.202e+00  exp= 2.805e-01  alpha= 1.068e-01  thy= 1.931e-01  shift= 0.000e+00  chi2=     0.670  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.235e-01  pT= 3.960e-01  Q2= 9.202e+00  exp= 2.654e-01  alpha= 1.063e-01  thy= 2.010e-01  shift= 0.000e+00  chi2=     0.367  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.437e-01  pT= 8.938e-02  Q2= 9.202e+00  exp= 5.218e-02  alpha= 3.414e-02  thy= 4.483e-02  shift= 0.000e+00  chi2=     0.046  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.304e-01  pT= 1.962e-01  Q2= 9.202e+00  exp= 1.748e-01  alpha= 7.345e-02  thy= 9.510e-02  shift= 0.000e+00  chi2=     1.176  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.352e-01  pT= 2.992e-01  Q2= 9.202e+00  exp= 1.606e-01  alpha= 6.818e-02  thy= 1.206e-01  shift= 0.000e+00  chi2=     0.343  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 5.391e-01  pT= 4.013e-01  Q2= 9.206e+00  exp= 1.781e-01  alpha= 7.564e-02  thy= 1.268e-01  shift= 0.000e+00  chi2=     0.462  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.335e-01  pT= 5.128e-01  Q2= 9.202e+00  exp= 1.156e-01  alpha= 4.674e-02  thy= 1.205e-01  shift= 0.000e+00  chi2=    -0.011  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.236e-01  pT= 1.036e-01  Q2= 1.835e+00  exp= 1.373e-01  alpha= 2.129e-02  thy= 1.752e-01  shift= 0.000e+00  chi2=    -3.163  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 2.726e-01  pT= 1.026e-01  Q2= 1.835e+00  exp= 1.228e-01  alpha= 1.834e-02  thy= 1.150e-01  shift= 0.000e+00  chi2=     0.180  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 3.342e-01  pT= 9.959e-02  Q2= 1.835e+00  exp= 7.792e-02  alpha= 1.147e-02  thy= 6.727e-02  shift= 0.000e+00  chi2=     0.862  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.156e-01  pT= 1.025e-01  Q2= 1.835e+00  exp= 3.022e-02  alpha= 4.592e-03  thy= 3.800e-02  shift= 0.000e+00  chi2=    -2.868  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 4.186e-01  pT= 2.021e-01  Q2= 1.835e+00  exp= 7.509e-02  alpha= 1.103e-02  thy= 6.582e-02  shift= 0.000e+00  chi2=     0.705  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.277e-01  pT= 9.925e-02  Q2= 1.835e+00  exp= 1.620e-02  alpha= 2.554e-03  thy= 1.925e-02  shift= 0.000e+00  chi2=    -1.430  ',
#  u'col= hermes  obs=M_Hermes  x= 9.568e-02  z= 5.315e-01  pT= 1.983e-01  Q2= 1.835e+00  exp= 3.692e-02  alpha= 5.623e-03  thy= 3.435e-02  shift= 0.000e+00  chi2=     0.210  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.257e-01  pT= 9.959e-02  Q2= 2.882e+00  exp= 1.587e-01  alpha= 2.432e-02  thy= 1.538e-01  shift= 0.000e+00  chi2=     0.041  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 2.730e-01  pT= 1.007e-01  Q2= 2.882e+00  exp= 1.079e-01  alpha= 1.651e-02  thy= 1.002e-01  shift= 0.000e+00  chi2=     0.219  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.326e-01  pT= 1.004e-01  Q2= 2.882e+00  exp= 7.445e-02  alpha= 1.086e-02  thy= 5.866e-02  shift= 0.000e+00  chi2=     2.115  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 3.336e-01  pT= 2.007e-01  Q2= 2.882e+00  exp= 1.246e-01  alpha= 1.822e-02  thy= 9.963e-02  shift= 0.000e+00  chi2=     1.880  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.206e-01  pT= 1.005e-01  Q2= 2.882e+00  exp= 2.923e-02  alpha= 4.426e-03  thy= 2.985e-02  shift= 0.000e+00  chi2=    -0.019  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 4.225e-01  pT= 2.041e-01  Q2= 2.882e+00  exp= 5.649e-02  alpha= 8.685e-03  thy= 5.234e-02  shift= 0.000e+00  chi2=     0.229  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.325e-01  pT= 9.954e-02  Q2= 2.882e+00  exp= 1.239e-02  alpha= 2.210e-03  thy= 1.493e-02  shift= 0.000e+00  chi2=    -1.317  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.299e-01  pT= 2.019e-01  Q2= 2.882e+00  exp= 3.446e-02  alpha= 5.401e-03  thy= 2.754e-02  shift= 0.000e+00  chi2=     1.639  ',
#  u'col= hermes  obs=M_Hermes  x= 1.520e-01  z= 5.306e-01  pT= 3.014e-01  Q2= 2.882e+00  exp= 4.106e-02  alpha= 6.587e-03  thy= 3.449e-02  shift= 0.000e+00  chi2=     0.995  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.235e-01  pT= 1.053e-01  Q2= 5.223e+00  exp= 1.116e-01  alpha= 2.195e-02  thy= 1.561e-01  shift= 0.000e+00  chi2=    -4.110  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.716e-01  pT= 1.021e-01  Q2= 5.223e+00  exp= 8.717e-02  alpha= 1.670e-02  thy= 9.330e-02  shift= 0.000e+00  chi2=    -0.135  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 2.730e-01  pT= 2.045e-01  Q2= 5.223e+00  exp= 1.966e-01  alpha= 3.462e-02  thy= 1.496e-01  shift= 0.000e+00  chi2=     1.840  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.362e-01  pT= 1.027e-01  Q2= 5.223e+00  exp= 7.768e-02  alpha= 1.296e-02  thy= 5.030e-02  shift= 0.000e+00  chi2=     4.461  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 3.321e-01  pT= 2.044e-01  Q2= 5.223e+00  exp= 9.827e-02  alpha= 1.807e-02  thy= 8.625e-02  shift= 0.000e+00  chi2=     0.443  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.150e-01  pT= 9.772e-02  Q2= 5.223e+00  exp= 1.792e-02  alpha= 4.052e-03  thy= 2.507e-02  shift= 0.000e+00  chi2=    -3.117  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.204e-01  pT= 2.037e-01  Q2= 5.223e+00  exp= 6.738e-02  alpha= 1.200e-02  thy= 4.267e-02  shift= 0.000e+00  chi2=     4.240  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 4.172e-01  pT= 3.011e-01  Q2= 5.223e+00  exp= 9.386e-02  alpha= 1.562e-02  thy= 5.028e-02  shift= 0.000e+00  chi2=     7.778  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.271e-01  pT= 1.013e-01  Q2= 5.223e+00  exp= 1.027e-02  alpha= 2.493e-03  thy= 1.212e-02  shift= 0.000e+00  chi2=    -0.552  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.270e-01  pT= 2.138e-01  Q2= 5.223e+00  exp= 2.021e-02  alpha= 5.216e-03  thy= 2.206e-02  shift= 0.000e+00  chi2=    -0.125  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.342e-01  pT= 3.011e-01  Q2= 5.223e+00  exp= 2.032e-02  alpha= 5.379e-03  thy= 2.467e-02  shift= 0.000e+00  chi2=    -0.654  ',
#  u'col= hermes  obs=M_Hermes  x= 2.530e-01  z= 5.302e-01  pT= 4.000e-01  Q2= 5.223e+00  exp= 3.980e-02  alpha= 8.159e-03  thy= 2.536e-02  shift= 0.000e+00  chi2=     3.133  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.233e-01  pT= 8.262e-02  Q2= 9.202e+00  exp= 2.211e-01  alpha= 9.156e-02  thy= 1.248e-01  shift= 0.000e+00  chi2=     1.107  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.206e-01  pT= 1.993e-01  Q2= 9.202e+00  exp= 3.741e-01  alpha= 1.475e-01  thy= 2.415e-01  shift= 0.000e+00  chi2=     0.808  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 2.655e-01  pT= 1.286e-01  Q2= 9.206e+00  exp= 1.123e-01  alpha= 4.969e-02  thy= 1.152e-01  shift= 0.000e+00  chi2=    -0.003  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 2.745e-01  pT= 2.144e-01  Q2= 9.206e+00  exp= 1.514e-01  alpha= 8.092e-02  thy= 1.418e-01  shift= 0.000e+00  chi2=     0.014  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 2.689e-01  pT= 3.002e-01  Q2= 9.202e+00  exp= 2.491e-01  alpha= 1.204e-01  thy= 1.536e-01  shift= 0.000e+00  chi2=     0.630  ',
#  u'col= hermes  obs=M_Hermes  x= 4.088e-01  z= 3.391e-01  pT= 9.939e-02  Q2= 9.194e+00  exp= 5.997e-02  alpha= 3.294e-02  thy= 4.451e-02  shift= 0.000e+00  chi2=     0.220  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 3.345e-01  pT= 1.984e-01  Q2= 9.206e+00  exp= 1.214e-01  alpha= 4.807e-02  thy= 7.649e-02  shift= 0.000e+00  chi2=     0.871  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 3.287e-01  pT= 2.984e-01  Q2= 9.202e+00  exp= 1.838e-01  alpha= 6.281e-02  thy= 8.769e-02  shift= 0.000e+00  chi2=     2.339  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.100e-01  pT= 9.783e-02  Q2= 9.202e+00  exp= 4.203e-02  alpha= 1.812e-02  thy= 2.365e-02  shift= 0.000e+00  chi2=     1.030  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 4.084e-01  pT= 2.077e-01  Q2= 9.206e+00  exp= 8.821e-02  alpha= 3.146e-02  thy= 4.178e-02  shift= 0.000e+00  chi2=     2.177  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 4.244e-01  pT= 3.215e-01  Q2= 9.206e+00  exp= 6.730e-02  alpha= 3.723e-02  thy= 4.090e-02  shift= 0.000e+00  chi2=     0.503  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 4.255e-01  pT= 3.868e-01  Q2= 9.202e+00  exp= 8.263e-02  alpha= 3.870e-02  thy= 3.771e-02  shift= 0.000e+00  chi2=     1.347  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 5.485e-01  pT= 1.092e-01  Q2= 9.206e+00  exp= 1.321e-02  alpha= 1.010e-02  thy= 9.434e-03  shift= 0.000e+00  chi2=     0.140  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 5.183e-01  pT= 2.054e-01  Q2= 9.206e+00  exp= 1.708e-02  alpha= 1.685e-02  thy= 1.909e-02  shift= 0.000e+00  chi2=    -0.014  ',
#  u'col= hermes  obs=M_Hermes  x= 4.090e-01  z= 5.369e-01  pT= 3.175e-01  Q2= 9.202e+00  exp= 4.770e-02  alpha= 2.288e-02  thy= 1.972e-02  shift= 0.000e+00  chi2=     1.496  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 5.402e-01  pT= 3.863e-01  Q2= 9.206e+00  exp= 2.240e-02  alpha= 2.101e-02  thy= 1.875e-02  shift= 0.000e+00  chi2=     0.030  ',
#  u'col= hermes  obs=M_Hermes  x= 4.091e-01  z= 5.295e-01  pT= 5.005e-01  Q2= 9.206e+00  exp= 2.419e-02  alpha= 1.742e-02  thy= 1.624e-02  shift= 0.000e+00  chi2=     0.208  ']

# %% [markdown]
# ### plot data and theory

# %%
data=load('%s/%s'%(path2results,'data_and_thy.dat'))

# %%
data
# Out:
# {}

# %% [markdown]
# ### 1000

# %%
tab=pd.DataFrame(data['sidis']['tabs']['hermes']).query('idx==1000')
tab['xr']=[np.round(x,2) for x in tab.x]
ZR=[[0.1,0.2],[0.2,0.25],[0.25,0.3],[0.3,0.4],[0.4,0.5],[0.5,1]]

nrows,ncols=1,2
fig = py.figure(figsize=(ncols*3,nrows*3))
ax=py.subplot(nrows,ncols,1)
ax.plot(tab['x'],tab['Q2'],'.'); ax.set_xlabel(r'$x$',size=20); ax.set_ylabel(r'$Q^2$',size=20)
ax=py.subplot(nrows,ncols,2)
ax.plot(tab['pT'],tab['z'],'.'); ax.set_xlabel(r'$p_T$',size=20); ax.set_ylabel(r'$z$',size=20);
for zr in ZR: ax.axhline(y=zr[0]);
py.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-01d94df9ef92> in <module>()
# ----> 1 tab=pd.DataFrame(data['sidis']['tabs']['hermes']).query('idx==1000')
#       2 tab['xr']=[np.round(x,2) for x in tab.x]
#       3 ZR=[[0.1,0.2],[0.2,0.25],[0.25,0.3],[0.3,0.4],[0.4,0.5],[0.5,1]]
#       4
#       5 nrows,ncols=1,2
#
# KeyError: 'sidis'

# %%
nrows,ncols=6,6
fig = py.figure(figsize=(ncols*3,nrows*2))
cnt=0
for xr in np.unique(tab['xr']):
    tabx=tab.query('xr==%f'%xr)
    for zr in ZR:
        tabz=tabx.query('z>%f and z<%f'%(zr[0],zr[1]))
        cnt+=1
        ax=py.subplot(nrows,ncols,cnt)
        ax.errorbar(tabz['pT'],tabz['exp'],yerr=tabz['alpha'],fmt='k.')
        ax.fill_between(tabz['pT'],tabz['thy']-tabz['dthy'],tabz['thy']+tabz['dthy'])
        
py.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-23a0f7284066> in <module>()
#       2 fig = py.figure(figsize=(ncols*3,nrows*2))
#       3 cnt=0
# ----> 4 for xr in np.unique(tab['xr']):
#       5     tabx=tab.query('xr==%f'%xr)
#       6     for zr in ZR:
#
# NameError: name 'tab' is not defined

# %%
pwd
# Out:
# u'/Users/avp5627/GIT/TMD-PHENO-REPOS/fitpack/fitlab/notebooks'

# %%
from plotter import Plotter
from matplotlib import rc
import matplotlib.pyplot as plt

rc("font", **{"family": "sans-serif", "sans-serif": ["Helvetica"]})

#conf = load_config("../fitlab/inputs/upol_hermes_noevolution.py")

#conf["resman"] = RESMAN(conf)
#conf["resman"].get_residuals(conf["parman"].par)



x_bins = [0.023, 0.047, 0.075, 0.12, 0.2, 0.35, 0.6]
q2_bins = [1.0, 15.0]



raw = pd.read_excel('../database/sidis/expdata/1002.xlsx')

data = pd.concat(pd.DataFrame(d)
                 for d in conf["resman"].sidisres.tabs.values())

data = data[(data["hadron"] == "k+") &
            (data["target"] == "proton")]

z_bin_edges = [0.1 , 0.2 , 0.25 , 0.3 , 0.375 , 0.475 , 0.6 , 0.8 , 1.1]
z_bins = list(zip(z_bin_edges[:], z_bin_edges[1:]))

def z_func(z):
    for k, (zmin, zmax) in enumerate(z_bins):
        if (z <= zmax) and ((zmin < z) or (k == 0 and zmin <= z)):
            return k

z_ids = tuple(range(8))

z_labs = {
    0: r"$z \in \left[ 0.1, 0.2 \right]$",
    1: r"$z \in \left( 0.2, 0.25 \right]$",
    2: r"$z \in \left( 0.25, 0.3 \right]$",
    3: r"$z \in \left( 0.3, 0.375 \right]$",
    4: r"$z \in \left( 0.375, 0.475 \right]$",
    5: r"$z \in \left( 0.475, 0.6 \right]$",
    6: r"$z \in \left( 0.6, 0.8 \right]$",
    7: r"$z \in \left( 0.8, 1.1 \right]$"
}

raw["qT"] = raw["pT"] / raw["z"]
data["qT"] = data["pT"] / data["z"]

col_lab = "pT"
sub_xlabel = r"$p_T$ (GeV)"

big_xlabel = "$x$"
big_ylabel = "$Q^2$"

title = "HERMES"

sub_ylabel = r"$M_{D}^{\pi^+}$"

fig_kw = {"figsize": (13, 13)}

plotter = Plotter(raw=raw,
                  data=data,
                  col_lab=col_lab,
                  q2_bins=q2_bins,
                  x_bins=x_bins,
                  z_func=z_func,
                  z_ids=z_ids,
                  z_labs=z_labs,
                  sub_xlabel=sub_xlabel,
                  sub_ylabel=sub_ylabel,
                  big_xlabel=big_xlabel,
                  big_ylabel=big_ylabel,
                  title=title,
                  fig_kw=fig_kw
                  )

plotter.raw_plot_kw["alpha"] = 0.4
 
plotter.raw_plot_kw["markersize"] = 2
plotter.raw_plot_kw["linewidth"] = 2

plotter.data_plot_kw["alpha"] = 1.0
plotter.data_plot_kw["markersize"] = 2.4
plotter.data_plot_kw["linewidth"] = 2
plotter.data_plot_kw["markeredgecolor"] = (0.8392156862745098,
                                           0.15294117647058825,
                                           0.1568627450980392)  # To increase visibility
plotter.data_plot_kw["markeredgewidth"] = 0.16

plotter.legend_kw["bbox_to_anchor"] = (0.9 / plotter.ncols, 1 - 0.5 / plotter.nrows)
plotter.legend_kw["loc"] = "center"

# %%
plotter.plot()

# %%
from matplotlib import rc
rc("font", **{"family": "sans-serif", "sans-serif": ["Helvetica"]})


data = pd.concat(pd.DataFrame(d)
                 for d in conf["resman"].sidisres.tabs.values())

data = data[(data["hadron"] == "pi+") &
            (data["target"] == "proton")]

# %%
#####################
# reading the data ##
#####################
#dat=pd.read_excel('E:/Laptop/School/Interships/Dr_Prokudin/Juniper82/PHYS296/dat/expdat/1000.xlsx');
#dat=pd.read_excel('C:/Users/Dolam/Documents/Scott/1000.xlsx');
dat=pd.read_excel('../database/sidis/expdata/1000.xlsx');

# %%
######################
# Calculated values ##
######################
dat["delta"] = np.sqrt(dat["stat_u"]**2.0) # measurment error

data["delta"] = np.sqrt(data["stat_u"]**2.0) # measurment error

# %%
##################
## Binning data ##
##################
# data bin edeges

xBin=np.array([0.023,0.047,0.075,0.12,0.35,0.6]) # Bins for x used to plot Pt
Q2Bin=np.array([1.0,10]) # **NOTE** includes all Q2 data, therefore all value data is plotted vs. Pt
zBin= np.array([0.1, 0.2,0.25,0.3, 0.375, 0.475, 0.6, 0.8, 1.1]) # catagories for z to be ploted indiviualy in each subplot

# binning data
dat['xBin'] = pd.cut(dat['x'], xBin,labels = False, retbins=0)
dat['Q2Bin'] = pd.cut(dat['Q2'], Q2Bin,labels = False, retbins=0)
dat['zBin'] = pd.cut(dat['z'], zBin,labels = False, retbins=0)

data['xBin'] = pd.cut(data['x'], xBin,labels = False, retbins=0)
data['Q2Bin'] = pd.cut(data['Q2'], Q2Bin,labels = False, retbins=0)
data['zBin'] = pd.cut(data['z'], zBin,labels = False, retbins=0)

# bins for x and y that have non-empty intersection
pTdatmod=[0,1,2,3,4] # xBins that overlap Q2Bins
valuedatmod=[0] # Q2bins that overlap xBins

# %%
###############
# HermesPlot ##
###############  Reduced matix 
# initialize the figure
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from matplotlib.backends.backend_pdf import PdfPages

fig1=plt.figure(figsize=(18, 4),facecolor="white") # figsize; wxh in inche
globalGrid=gridspec.GridSpec(1, 1,left=0.03,right=1,top=.91,bottom=.115, wspace=0.0, hspace=0.0) # plot for subplot matrix as 1x1 matrix
innerGrid=gridspec.GridSpecFromSubplotSpec(1,5 , subplot_spec=globalGrid[0], wspace=0.0, hspace=0.0) # 5x6 subplot grid 

# figure properties:
ax=fig1.add_axes([0,0,1,1]) # axas for subplot matrix as percent of hole
#ax.yaxis.set_ticks([0,1.25,2.76,4.27,5.78,7.29,8.8,10])
ax.xaxis.set_ticks([0,1.25,2.8,4.35,5.9,7.45,9,10 ])
xticklabels = np.array([0,0.023,0.047,0.075,0.12,0.35,0.6]) 

ax.set_yticklabels("")
ax.set_xticklabels(xticklabels)
ax.set_xlabel(r"$x$ bins") # xy-lables
ax.set_ylabel(r"$Q^2$",rotation="horizontal",labelpad = 15)
#ax.grid() # grid currently off

# subplot axis proerties (unused)
Zcolor=['#F74902',"green","blue",'orange',"#7851a9","brown",'#093162','#4b5320']
Zmark=["o","o","o","o"]

# Set legend
Zpatch1 = mpatches.Patch(color=Zcolor[0], label='0.1<z<0.2')
Zpatch2 = mpatches.Patch(color=Zcolor[1], label='0.2<z<0.25')
Zpatch3 = mpatches.Patch(color=Zcolor[2], label='0.25<z<0.3')
Zpatch4 = mpatches.Patch(color=Zcolor[3], label='0.3<z<0.375')
Zpatch5 = mpatches.Patch(color=Zcolor[4], label='0.375<z<0.475')
Zpatch6 = mpatches.Patch(color=Zcolor[5], label='0.475<z<0.6')
Zpatch7 = mpatches.Patch(color=Zcolor[6], label='0.6<z<0.8')
Zpatch8 = mpatches.Patch(color=Zcolor[7], label='0.8<z<1')
          
ax.legend(handles=[Zpatch1,Zpatch2,Zpatch3,Zpatch4,Zpatch5,Zpatch6,Zpatch7,Zpatch8],
          loc='upper center',
          ncol=8,prop={'size': 9}
          )
          
for f,F in zip(range(len(pTdatmod)),pTdatmod):       
    for j,J in zip(range(len(valuedatmod)),valuedatmod):
        
        k = int(f) # kth possition for subplot on innerGrid matrix
        maskX = dat['xBin'].isin([F]) # returns boolean for all Jth xBin in dat  
        maskY = dat['Q2Bin'].isin([J]) # returns boolean for all Fth Q2Bin in dat
        
        maskX_thr = data['xBin'].isin([F]) # returns boolean for all Jth xBin in dat  
        maskY_thr = data['Q2Bin'].isin([J]) # returns boolean for all Fth Q2Bin in dat
       
        ax = fig1.add_subplot(innerGrid[k]) # add subplot in innerGrid
        xydat = dat[maskX & maskY] # subset of data for Jth xBin and Fth Q2Bin
        
        xydata = data[maskX_thr & maskY_thr] # subset of data for Jth xBin and Fth Q2Bin
        
        for z in range(len(zBin)-1): 
            maskZ = xydat["zBin"].isin([z])
            databin = xydat[maskZ]
            
            maskZ_thr = xydata["zBin"].isin([z])
            databin_thr = xydata[maskZ_thr]
            
            if f != 0:
                ax.errorbar(databin['pT'],databin['value'],yerr=databin['delta'],capsize=5,linestyle="",color = Zcolor[z],elinewidth=1.25)
                ax.set_xlabel(r"$p_T$ (GeV)",labelpad=1)
                ax.set_yscale('log')
                ax.set_yticklabels('')
                
                ax.plot(databin_thr['pT'],databin_thr['thy'],linestyle="-",color = Zcolor[z]) # theory
                ax.fill_between(databin_thr['pT'],databin_thr['thy']-databin_thr['dthy'],databin_thr['thy']+databin_thr['dthy']) # theory error
                ax.set_xlabel(r"$P_{hT}$ (GeV)",labelpad=1)
                ax.set_yticklabels('')
               
            else:
                ax.errorbar(databin['pT'],databin['value'],yerr=databin['delta'],capsize=5,linestyle="", color = Zcolor[z],elinewidth=1.25)
                
                ax.plot(databin_thr['pT'],databin_thr['thy'],linestyle="-",color = Zcolor[z]) #theory
                ax.fill_between(databin_thr['pT'],databin_thr['thy']-databin_thr['dthy'],databin_thr['thy']+databin_thr['dthy']) # theory error

                
                ax.set_xlabel(r"$P_{hT}$ (GeV)",labelpad=1)
                ax.set_yscale('log')
plt.savefig("hermes_fit.pdf")
