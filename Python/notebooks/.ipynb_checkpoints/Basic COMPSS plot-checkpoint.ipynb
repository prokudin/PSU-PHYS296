# %%
import os
import pandas as pd
from pandas import read_excel as read
from pandas import DataFrame as df
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import string
# enable plots in the notebook
# %matplotlib inline

# %%
## Set working directory
os.chdir('../') # move dir back one 
current = os.getcwd() # get current dir
print "Moved Working directory back  %s" % current # check current dir


path = current+'\\database\\sidis\\expdata\\'
os.chdir(path) # one dir back
# Check 
newDir = os.getcwd() # get current dir
print "Working directory for data %s" % newDir # check current dir

## Grabing list of files
data=os.listdir('./') # list all files in dir
data=[files for files in data if files.endswith('.xlsx') and not files.startswith('~')] # list of COMPASS data
print "Data files retrieved %s" % data
# Out:
# Moved Working directory back  E:\Laptop\School\Fa_17\Phys296\GIT\PSU-PHYS296\Python
# Working directory for data E:\Laptop\School\Fa_17\Phys296\GIT\PSU-PHYS296\Python\database\sidis\expdata
# Data files retrieved ['1000.xlsx', '1001.xlsx', '1002.xlsx', '1003.xlsx', '1004.xlsx', '1005.xlsx', '1006.xlsx', '1007.xlsx', '2000.xlsx', '2001.xlsx', '2002.xlsx', '5001.xlsx', '5002.xlsx']

# %%
## Reading and resructuring data

data5001 = df(read(data[-2]))

# Calculate mesurment error
data5001["delta"] = (data5001["stat_u"]**2.0+data5001["sys_u"]**2.0)**(1/2.0)

##Binning data
xBin=[0.003,0.008,0.013,0.02,0.032,0.055,0.1,0.21,0.4]
Q2Bin=[1,1.7,3,7,16,81]

data5001['xClas'] = pd.cut(data5001['x'], xBin, labels=map(chr, range(97, 97+len(xBin)-1)))
data5001['xBin'] = pd.cut(data5001['x'], xBin)

data5001['Q2Clas'] = pd.cut(data5001['Q2'], Q2Bin, labels=map(chr, range(65, 65+len(Q2Bin)-1)))
data5001['Q2Bin'] = pd.cut(data5001['Q2'], Q2Bin)

#print "x bins \n%s \n%s\n Q2 bins \n%s \n%s" \
#    %(pd.value_counts(data5001['xBin']),pd.value_counts(data5001['xClas']), \
#      pd.value_counts(data5001['Q2Bin']),pd.value_counts(data5001['Q2Clas']))

print data5001.head()
# Out:
#    Ebeam      x    Q2      y    z        pT   pT2        obs   value  stat_u  \
# 0    160  0.157  20.0  0.439  0.2  0.300000  0.09  M_Compass  6.2719  0.3126
# 1    160  0.157  20.0  0.439  0.2  0.331662  0.11  M_Compass  6.2175  0.3135
# 2    160  0.157  20.0  0.439  0.2  0.360555  0.13  M_Compass  5.0537  0.2711
# 3    160  0.157  20.0  0.439  0.2  0.400000  0.16  M_Compass  4.8854  0.2244
# 4    160  0.157  20.0  0.439  0.2  0.424264  0.18  M_Compass  4.1757  0.2275
#
#     sys_u    target hadron      col     delta xClas         xBin Q2Clas  \
# 0  0.1051  deuteron    pi+  compass  0.329795     g  (0.1, 0.21]      E
# 1  0.1047  deuteron    pi+  compass  0.330521     g  (0.1, 0.21]      E
# 2  0.1070  deuteron    pi+  compass  0.291452     g  (0.1, 0.21]      E
# 3  0.1067  deuteron    pi+  compass  0.248476     g  (0.1, 0.21]      E
# 4  0.1101  deuteron    pi+  compass  0.252741     g  (0.1, 0.21]      E
#
#           Q2Bin
# 0  (16.0, 81.0]
# 1  (16.0, 81.0]
# 2  (16.0, 81.0]
# ...

# %%
##set perameters
groups=[['a','A'],['a','B'], ['b','A'], ['b','B'], ['c','A'], ['c','B'], ['c','C'], ['d','A'], ['d','B'], ['d','C'], ['e','A'],
        ['e','B'], ['e','C'], ['e','D'], ['f','B'], ['f','C'], ['f','D'], ['g','C'], ['g','D'], ['g','E'], ['h','D'], ['h','E']]
z=[0.2,0.3,0.4,0.6]
xlim,Q2lim=[0.0,0.4],[0.0,81.0]
gridmap=[6,7,12,13,14,15,18,19,20,21,22,24,25,26,27,28,29,32,33,34,35,36] #map of subplots on 5x8 grid
#print data5001['x'][(data5001['x']>=0.003) and (data5001['x']<0.008)]
#print data5001[data5001['x']<0.008 and data5001['x']<0.008 ]
#print type(group)

# %%
#testing
def plot(group):
    data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s" '%(group[0],group[1]))
    
    plt.errorbar(data_bin.pT2,data_bin.value,data_bin.delta,
                 fmt='o',mfc='green',
                 ecolor='green',capsize=5)
#    plt.title('x bin: "%s"\nQ2 bin: "%s"' %(data_bin.xBin,data_bin.Q2Bin))
    plt.xlabel('pT2')
#    plt.ylabel('"%s"' %data_bin.col[0])
plot(groups[0])

# %%
for group,grid in zip(range(len(groups)),gridmap):
    print groups[group][0]
    print groups[group][1]
    print grid
#for group in range(len(groups)):
#    print groups[group][0]
#    print groups[group][1]
print count
# Out:
# a
# A
# 6
# a
# B
# 7
# b
# A
# 12
# b
# B
# 13
# c
# A
# 14
# c
# B
# 15
# c
# C
# 18
# d
# A
# 19
# d
# B
# 20
# d
# C
# 21
# e
# A
# 22
# e
# B
# 24
# e
# C
# 25
# e
# D
# 26
# f
# B
# 27
# f
# C
# 28
# f
# D
# 29
# g
# C
# 32
# g
# D
# 33
# g
# E
# 34
# h
# D
# 35
# h
# E
# 36
# 88

# %%
#gridspec={"nrows": 4,"ncols":6,"left":0.5, "bottom":0.5, "right":0.9, "top":0.9,
#          "wspace":None, "hspace"=None, "width_ratios":None, "height_ratios":None}

fig=plt.figure(figsize=(10, 10),facecolor="gray") # figsize=wxh in inches

globalGrid=gridspec.GridSpec(1, 1, wspace=0.0, hspace=0.0) #the axis to put subplot grid in
innerGrid=gridspec.GridSpecFromSubplotSpec(5, 8, subplot_spec=globalGrid[0], wspace=0.0, hspace=0.0) #subplot grid

#ax=fig.add_subplot(globalGrid[0])
ax=fig.add_axes([0,0,1,1],xlim=xlim,ylim=Q2lim)
#ax.yaxis.set_ticks([1,1.7,3,7,16,81])
#ax.xaxis.set_ticks([0.003,0.008,0.013,0.02,0.032,0.055,0.1,0.21,0.4])

count=0
for group,grid in zip(range(len(groups)),gridmap):
    data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[group][0],groups[group][1]))
    for i in z:
#        ax = plt.Subplot(fig, innerGrid[grid]) #creats a new sub ax over the previous 
        ax = fig.add_subplot(innerGrid[grid])
        ax.set_yscale("log")
        count+=1
        ax.errorbar(data_bin.pT2[data_bin.z==i],data_bin.value[data_bin.z==i],
                   data_bin.delta[data_bin.z==i])
#        fig.add_subplot(ax)

# %%
## Figure axes with sub-axis
groups=['a','A'], ['a','B'], ['b','A'], ['b','B'], ['c','A'], ['c','B'], ['c','C'], ['d','A'], ['d','B'], ['d','C'], ['e','A'],['e','B'], ['e','C'], ['e','D'], ['f','B'], ['f','C'], ['f','D'], ['g','C'], ['g','D'], ['g','E'], ['h','D'], ['h','E']
        

z=[0.2,0.3,0.4,0.6]

xlim=[0.0,0.4]
Q2lim=[0.0,81.0]

fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1],xlim=xlim,ylim=Q2lim)# Figure limits [left, bottom, width, height] 

#for g in group
g=0
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax2 = fig.add_axes([xBin[0]/xlim[1],Q2Bin[0]/Q2lim[1],xBin[1]/xlim[1],Q2Bin[1]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax2.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax2.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax2.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax2.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot 

g=1
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax3 = fig.add_axes([xBin[0]/xlim[1],Q2Bin[1]/Q2lim[1],xBin[1]/xlim[1],Q2Bin[2]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax3.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax3.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax3.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax3.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot 
g=2
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax4 = fig.add_axes([xBin[1]/xlim[1],Q2Bin[0]/Q2lim[1],xBin[2]/xlim[1],Q2Bin[1]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax4.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax4.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax4.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax4.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot 

g=3
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax5 = fig.add_axes([xBin[1]/xlim[1],Q2Bin[1]/Q2lim[1],xBin[2]/xlim[1],Q2Bin[2]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax5.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax5.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax5.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax5.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot 

g=4
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax6 = plt.axes([xBin[2]/xlim[1],Q2Bin[0]/Q2lim[1],xBin[3]/xlim[1],Q2Bin[1]/Q2lim[1]],
               xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
               ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax6.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax6.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax6.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax6.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot 

g=5
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax7 = fig.add_axes([xBin[2]/xlim[1],Q2Bin[1]/Q2lim[1],xBin[3]/xlim[1],Q2Bin[2]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax7.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax7.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax7.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax7.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot 

g=6
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax8 = fig.add_axes([xBin[2]/xlim[1],Q2Bin[2]/Q2lim[1],xBin[3]/xlim[1],Q2Bin[3]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax8.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax8.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax8.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax8.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=7
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax9 = fig.add_axes([xBin[3]/xlim[1],Q2Bin[0]/Q2lim[1],xBin[4]/xlim[1],Q2Bin[1]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax9.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax9.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax9.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax9.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=8
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax10 = fig.add_axes([xBin[3]/xlim[1],Q2Bin[1]/Q2lim[1],xBin[4]/xlim[1],Q2Bin[2]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax10.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax10.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax10.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax10.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=9
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax11 = fig.add_axes([xBin[3]/xlim[1],Q2Bin[2]/Q2lim[1],xBin[4]/xlim[1],Q2Bin[3]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax11.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax11.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax11.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax11.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=10
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax12 = fig.add_axes([xBin[4]/xlim[1],Q2Bin[0]/Q2lim[1],xBin[5]/xlim[1],Q2Bin[1]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax12.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax12.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax12.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax12.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=11
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax13 = fig.add_axes([xBin[4]/xlim[1],Q2Bin[1]/Q2lim[1],xBin[5]/xlim[1],Q2Bin[2]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax13.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax13.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax13.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax13.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=12
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax14 = fig.add_axes([xBin[4]/xlim[1],Q2Bin[2]/Q2lim[1],xBin[5]/xlim[1],Q2Bin[3]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax14.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax14.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax14.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax14.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=13
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax15 = fig.add_axes([xBin[5]/xlim[1],Q2Bin[1]/Q2lim[1],xBin[6]/xlim[1],Q2Bin[2]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax15.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax15.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax15.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax15.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=14
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax16 = fig.add_axes([xBin[5]/xlim[1],Q2Bin[2]/Q2lim[1],xBin[6]/xlim[1],Q2Bin[3]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax16.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax16.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax16.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax16.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=15
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax17 = fig.add_axes([xBin[5]/xlim[1],Q2Bin[3]/Q2lim[1],xBin[6]/xlim[1],Q2Bin[4]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax17.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax17.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax17.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax17.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=16
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax18 = fig.add_axes([xBin[6]/xlim[1],Q2Bin[2]/Q2lim[1],xBin[6]/xlim[1],Q2Bin[3]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax18.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax18.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax18.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax18.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=17
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax19 = fig.add_axes([xBin[6]/xlim[1],Q2Bin[3]/Q2lim[1],xBin[6]/xlim[1],Q2Bin[4]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax19.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax19.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax19.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax19.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=18
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax20 = fig.add_axes([xBin[6]/xlim[1],Q2Bin[4]/Q2lim[1],xBin[6]/xlim[1],Q2Bin[5]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax20.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax20.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax20.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax20.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=19
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax21 = fig.add_axes([xBin[7]/xlim[1],Q2Bin[3]/Q2lim[1],xBin[8]/xlim[1],Q2Bin[4]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax21.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax21.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax21.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax21.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot

g=20
data_bin=data5001.query('xClas=="%s" and Q2Clas=="%s"' %(groups[g][0],groups[g][1]))

#subplot x: 0.003, 0.008; Q2: 1, 1.7
ax22 = fig.add_axes([xBin[7]/xlim[1],Q2Bin[4]/Q2lim[1],xBin[8]/xlim[1],Q2Bin[5]/Q2lim[1]],
                   xlim=[data_bin.pT2.min(),data_bin.pT2.max()],
                   ylim=[data_bin.value.min(),data_bin.value.max()])
#for i in z
i=0
ax22.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='o',mfc='green',ecolor='green') # subplot 
i=1
ax22.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='s',mfc='red',ecolor='red') # subplot 
i=2
ax22.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='blue',ecolor='blue') # subplot 
i=3
ax22.errorbar(data_bin.pT2[data_bin.z==z[i]],data_bin.value[data_bin.z==z[i]],
             data_bin.delta[data_bin.z==z[i]],
             fmt='^',mfc='black',ecolor='black') # subplot
# Out:
# <Container object of 3 artists>

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))
ax3 = fig.add_axes([0.1,0.9,0.8,0.4])
