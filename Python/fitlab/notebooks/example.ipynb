# %% [markdown]
# # Transversity-Boer-Mulders Analysis

# %%
import sys
import os;os.chdir('../')
import itertools as it
import numpy as np
import pandas as pd
import pylab as py
from  matplotlib import rc
from matplotlib.colors import LogNorm
# %matplotlib inline
from tools.tools import save,load,lprint,load_config
from tools.bar import BAR
from fitlab.resman import RESMAN
from fitlab.parman import PARMAN
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)

# %%
conf=load_config('inputs/all.py')
conf['resman']=RESMAN(conf)
conf['resman'].get_residuals(conf['parman'].par);
# Out:
# loading sidis data sets 2001

# %% [markdown]
# ## Data vs Theory

# %%
all=pd.concat([pd.DataFrame(conf['resman'].sidisres.tabs[idx]) \
              for idx in conf['resman'].sidisres.tabs.keys()])

# %% [markdown]
# ## Collins asymmetry

# %%
def plot(ax,axis,col,tar):
    if axis=='pT':
        data_pip=all.query('dependence=="%s" and target=="%s" and hadron=="%s" and col=="%s" '%(axis,tar,'pi+',col))
        data_pim=all.query('dependence=="%s" and target=="%s" and hadron=="%s" and col=="%s" '%(axis,tar,'pi-',col))
    else:
        data_pip=all.query('dependence=="%s" and target=="%s" and hadron=="%s" and col=="%s" '%(axis,tar,'pi+',col))
        data_pim=all.query('dependence=="%s" and target=="%s" and hadron=="%s" and col=="%s" '%(axis,tar,'pi-',col))
    
    
    ax.errorbar(data_pip[axis],data_pip['value'],yerr=data_pip['alpha'],fmt='k.',label=r'$\pi^+$')
    ax.errorbar(data_pim[axis],data_pim['value'],yerr=data_pim['alpha'],fmt='ko', mfc='white',label=r'$\pi^-$',markersize=4)

    ax.plot(data_pip[axis].values,sign*data_pip['thy'].values,'r-')
    ax.plot(data_pim[axis].values,sign*data_pim['thy'].values,'b-')

    if tar=='proton': star='p'
    if tar=='deuteron': star='d'
 
    ax.set_title(r'${\rm target}=%s$'%(star))
    ax.set_xlabel(r'$%s$'%axis)
    #if axis=='x': ax.set_ylim(-0.05,0.05)

nrows,ncols=3,3
py.figure(figsize=(ncols*3,nrows*2))

cnt=0
for col in ['clas']:
    if col=='clas': targets=['proton']
    for tar in targets:
        for axis  in ['pT']:
            cnt+=1
            ax=py.subplot(nrows,ncols,cnt)
            plot(ax,axis,col,tar)
            if cnt==1: ax.legend()
py.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-9-dd6698d93da9> in <module>()
#      31             cnt+=1
#      32             ax=py.subplot(nrows,ncols,cnt)
# ---> 33             plot(ax,axis,col,tar)
#      34             if cnt==1: ax.legend()
#      35 py.tight_layout()
#
# <ipython-input-9-dd6698d93da9> in plot(ax, axis, col, tar)
#       1 def plot(ax,axis,col,tar):
#       2     if axis=='pT':
# ----> 3         data_pip=all.query('dependence=="%s" and target=="%s" and hadron=="%s" and col=="%s" '%(axis,tar,'pi+',col))
#       4         data_pim=all.query('dependence=="%s" and target=="%s" and hadron=="%s" and col=="%s" '%(axis,tar,'pi-',col))
#       5     else:
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in query(self, expr, inplace, **kwargs)
#    2208         kwargs['level'] = kwargs.pop('level', 0) + 1
#    2209         kwargs['target'] = None
# -> 2210         res = self.eval(expr, **kwargs)
#    2211
#    2212         try:
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in eval(self, expr, inplace, **kwargs)
#    2277             kwargs['target'] = self
#    2278         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 2279         return _eval(expr, inplace=inplace, **kwargs)
#    2280
#    2281     def select_dtypes(self, include=None, exclude=None):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/eval.pyc in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     259
#     260         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env,
# --> 261                            truediv=truediv)
#     262
#     263         # construct the engine and evaluate the parsed expression
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in __init__(self, expr, engine, parser, env, truediv, level)
#     723         self.env.scope['truediv'] = truediv
#     724         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 725         self.terms = self.parse()
#     726
#     727     @property
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in parse(self)
#     740     def parse(self):
#     741         """Parse an expression"""
# --> 742         return self._visitor.visit(self.expr)
#     743
#     744     @property
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit(self, node, **kwargs)
#     310         method = 'visit_' + node.__class__.__name__
#     311         visitor = getattr(self, method)
# --> 312         return visitor(node, **kwargs)
#     313
#     314     def visit_Module(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit_Module(self, node, **kwargs)
#     316             raise SyntaxError('only a single expression is allowed')
#     317         expr = node.body[0]
# --> 318         return self.visit(expr, **kwargs)
#     319
#     320     def visit_Expr(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit(self, node, **kwargs)
#     310         method = 'visit_' + node.__class__.__name__
#     311         visitor = getattr(self, method)
# --> 312         return visitor(node, **kwargs)
#     313
#     314     def visit_Module(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit_Expr(self, node, **kwargs)
#     319
#     320     def visit_Expr(self, node, **kwargs):
# --> 321         return self.visit(node.value, **kwargs)
#     322
#     323     def _rewrite_membership_op(self, node, left, right):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit(self, node, **kwargs)
#     310         method = 'visit_' + node.__class__.__name__
#     311         visitor = getattr(self, method)
# --> 312         return visitor(node, **kwargs)
#     313
#     314     def visit_Module(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit_BoolOp(self, node, **kwargs)
#     668
#     669         operands = node.values
# --> 670         return reduce(visitor, operands)
#     671
#     672 # ast.Call signature changed on 3.5,
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visitor(x, y)
#     660     def visit_BoolOp(self, node, **kwargs):
#     661         def visitor(x, y):
# --> 662             lhs = self._try_visit_binop(x)
#     663             rhs = self._try_visit_binop(y)
#     664
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in _try_visit_binop(self, bop)
#     656         if isinstance(bop, (Op, Term)):
#     657             return bop
# --> 658         return self.visit(bop)
#     659
#     660     def visit_BoolOp(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit(self, node, **kwargs)
#     310         method = 'visit_' + node.__class__.__name__
#     311         visitor = getattr(self, method)
# --> 312         return visitor(node, **kwargs)
#     313
#     314     def visit_Module(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit_Compare(self, node, **kwargs)
#     641             op = self.translate_In(ops[0])
#     642             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 643             return self.visit(binop)
#     644
#     645         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit(self, node, **kwargs)
#     310         method = 'visit_' + node.__class__.__name__
#     311         visitor = getattr(self, method)
# --> 312         return visitor(node, **kwargs)
#     313
#     314     def visit_Module(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit_BinOp(self, node, **kwargs)
#     413
#     414     def visit_BinOp(self, node, **kwargs):
# --> 415         op, op_class, left, right = self._possibly_transform_eq_ne(node)
#     416         left, right = self._possibly_downcast_constants(left, right)
#     417         return self._possibly_evaluate_binop(op, op_class, left, right)
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in _possibly_transform_eq_ne(self, node, left, right)
#     351     def _possibly_transform_eq_ne(self, node, left=None, right=None):
#     352         if left is None:
# --> 353             left = self.visit(node.left, side='left')
#     354         if right is None:
#     355             right = self.visit(node.right, side='right')
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit(self, node, **kwargs)
#     310         method = 'visit_' + node.__class__.__name__
#     311         visitor = getattr(self, method)
# --> 312         return visitor(node, **kwargs)
#     313
#     314     def visit_Module(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/expr.pyc in visit_Name(self, node, **kwargs)
#     427
#     428     def visit_Name(self, node, **kwargs):
# --> 429         return self.term_type(node.id, self.env, **kwargs)
#     430
#     431     def visit_NameConstant(self, node, **kwargs):
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/ops.pyc in __init__(self, name, env, side, encoding)
#      56         self.is_local = (tname.startswith(_LOCAL_TAG) or
#      57                          tname in _DEFAULT_GLOBALS)
# ---> 58         self._value = self._resolve_name()
#      59         self.encoding = encoding
#      60
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/ops.pyc in _resolve_name(self)
#      73
#      74     def _resolve_name(self):
# ---> 75         res = self.env.resolve(self.local_name, is_local=self.is_local)
#      76         self.update(res)
#      77
#
# /anaconda/lib/python2.7/site-packages/pandas/computation/scope.pyc in resolve(self, key, is_local)
#     188                 return self.temps[key]
#     189             except KeyError:
# --> 190                 raise compu.ops.UndefinedVariableError(key, is_local)
#     191
#     192     def swapkey(self, old_key, new_key, new_value=None):
#
# UndefinedVariableError: name 'dependence' is not defined

# %% [markdown]
# ## Boer-Mulders asymmetry

# %%
def plot(ax,axis,tar):
    data_pip=bm.query('axis=="%s" and target=="%s" and hadron=="%s" '%(axis,tar,'pi+'))
    data_pim=bm.query('axis=="%s" and target=="%s" and hadron=="%s" '%(axis,tar,'pi-'))
    if axis=='pt': axis='pT'
    ax.errorbar(data_pip[axis],data_pip['value'],yerr=data_pip['alpha'],fmt='k.',label=r'$\pi^+$')
    ax.errorbar(data_pim[axis],data_pim['value'],yerr=data_pim['alpha'],fmt='ko', mfc='white',label=r'$\pi^-$',markersize=4)

    ax.plot(data_pip[axis].values,data_pip['thy'].values,'r-')
    ax.plot(data_pim[axis].values,data_pim['thy'].values,'b-')

    if tar=='proton': star='p'
    if tar=='deuteron': star='d'
 
    ax.set_title(r'${\rm target}=%s$'%(star))
    ax.set_xlabel(r'$%s$'%axis)
    if axis=='x': ax.set_ylim(-0.05,0.05)

nrows,ncols=4,4
py.figure(figsize=(ncols*3,nrows*2))

cnt=0
for tar in ['proton','deuteron']:
    for axis  in ['x','y','z','pt']:
        cnt+=1
        ax=py.subplot(nrows,ncols,cnt)
        plot(ax,axis,tar)
        if cnt==1: ax.legend()
py.tight_layout()

# %% [markdown]
# ## Transversity

# %%
def plot(ax,iflav):
    X=10**np.linspace(-4,-1)
    X=np.append(X,np.linspace(0.1,1))
    Q2=1
    F=[conf['transversity'].get_C(x,Q2,target='p')[iflav] for x in X]
    ax.plot(X,F)

    ymin,ymax=ax.get_ylim()
    if   iflav==1: ax.set_ylim(0,1);ymin,ymax=ax.get_ylim()
    elif iflav==3: ax.set_ylim(-2,0);ymin,ymax=ax.get_ylim()
    xmin=np.amin(co.x.values)
    xmax=np.amax(co.x.values)
    dy=ymax-ymin
    ax.plot([xmin,xmax],[ymin+dy*0.1,ymin+dy*0.1],'g-')
    ax.set_ylim(ymin,ymax)
    ax.semilogx()
    
    if iflav==1: ax.set_title(r'${\rm flav=u}$',size=20)
    if iflav==3: ax.set_title(r'${\rm flav=d}$',size=20)
    if iflav==5: ax.set_title(r'${\rm flav=s}$',size=20)
    if iflav==2: ax.set_title(r'${\rm flav=\bar{u}}$',size=20)
    if iflav==4: ax.set_title(r'${\rm flav=\bar{d}}$',size=20)
    if iflav==6: ax.set_title(r'${\rm flav=\bar{s}}$',size=20)
    ax.set_xlabel(r'$x$',size=20)
    
nrows,ncols=2,3
py.figure(figsize=(ncols*3,nrows*3))
cnt=0
for iflav in [1,3,5,2,4,6]:
    cnt+=1
    ax=py.subplot(nrows,ncols,cnt)
    plot(ax,iflav)
py.tight_layout()

# %% [markdown]
# ## Boer-Mulders

# %%
def plot(ax,iflav):
    X=10**np.linspace(-2,-1)
    X=np.append(X,np.linspace(0.1,1))
    
    Q2=1
    F=[conf['boermulders'].get_C(x,Q2,target='p')[iflav] for x in X]
    ax.plot(X,F)

    ymin,ymax=ax.get_ylim()
    if   iflav==1: ax.set_ylim(-10,0);ymin,ymax=ax.get_ylim()
    elif iflav==3: ax.set_ylim(-10,0);ymin,ymax=ax.get_ylim()
    xmin=np.amin(bm.x.values)
    xmax=np.amax(bm.x.values)
    dy=ymax-ymin
    ax.plot([xmin,xmax],[ymin+dy*0.1,ymin+dy*0.1],'g-')
    ax.set_ylim(ymin,ymax)
    ax.semilogx()
    
    if iflav==1: ax.set_title(r'${\rm flav=u}$',size=20)
    if iflav==3: ax.set_title(r'${\rm flav=d}$',size=20)
    if iflav==5: ax.set_title(r'${\rm flav=s}$',size=20)
    if iflav==2: ax.set_title(r'${\rm flav=\bar{u}}$',size=20)
    if iflav==4: ax.set_title(r'${\rm flav=\bar{d}}$',size=20)
    if iflav==6: ax.set_title(r'${\rm flav=\bar{s}}$',size=20)
    ax.set_xlabel(r'$x$',size=20)

    
nrows,ncols=2,3
py.figure(figsize=(ncols*3,nrows*3))
cnt=0
for iflav in [1,3,5,2,4,6]:
    cnt+=1
    ax=py.subplot(nrows,ncols,cnt)
    plot(ax,iflav)
py.tight_layout()

# %% [markdown]
# ## Collins

# %%
def plot(ax,iflav):
    Z=np.linspace(0.2,1)
    Q2=1
    ZF=[conf['collins'].get_C(z,Q2,hadron='pi+')[iflav] for z in Z]
    ax.plot(Z,ZF)
    
    ymin,ymax=ax.get_ylim()
    #if   iflav==1: ax.set_ylim(-10,0);ymin,ymax=ax.get_ylim()
    #elif iflav==3: ax.set_ylim(-10,0);ymin,ymax=ax.get_ylim()
    xmin=np.amin(co.z.values)
    xmax=np.amax(co.z.values)
    dy=ymax-ymin
    ax.plot([xmin,xmax],[ymin+dy*0.1,ymin+dy*0.1],'g-')
    ax.set_ylim(ymin,ymax)
    #ax.semilogx()
    
    if iflav==1: ax.set_title(r'${\rm flav=u}$',size=20)
    if iflav==3: ax.set_title(r'${\rm flav=d}$',size=20)
    if iflav==5: ax.set_title(r'${\rm flav=s}$',size=20)
    if iflav==2: ax.set_title(r'${\rm flav=\bar{u}}$',size=20)
    if iflav==4: ax.set_title(r'${\rm flav=\bar{d}}$',size=20)
    if iflav==6: ax.set_title(r'${\rm flav=\bar{s}}$',size=20)
    ax.set_xlabel(r'$z$',size=20)

    
nrows,ncols=2,3
py.figure(figsize=(ncols*3,nrows*3))
cnt=0
for iflav in [1,3,5,2,4,6]:
    cnt+=1
    ax=py.subplot(nrows,ncols,cnt)
    plot(ax,iflav)
py.tight_layout()
